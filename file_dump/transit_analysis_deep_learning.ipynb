# %% [markdown]
# # Final TESS Transit Classification — Optimized for Extreme Class Imbalance
#
# This notebook converts and expands the provided Python script into a fully documented, didactic, and **step-by-step** workflow.
# We train a 1D CNN to classify TESS light curves into *transit* (planet candidate) vs *non-transit* under **severe class imbalance**.
#
# **Key strategies covered:**
#
# - **Balanced augmentation** (equal samples per class) to mitigate imbalance during training.
# - **Focal loss** (tunable `gamma` and `alpha`) to emphasize hard examples and rare positives.
# - **Threshold optimization** using **Youden’s J** from the ROC curve (don’t use the default 0.5).
# - **Simplified CNN architecture** to reduce overfitting.
# - **AUC-centric monitoring** with early stopping and LR scheduling.
#
# > **What you’ll learn**
# >
# > 1. Why balanced training batches help under extreme imbalance.
# > 2. How focal loss reshapes the gradient to focus on hard/rare samples.
# > 3. How to pick a **data-driven** decision threshold that best trades off TPR/FPR.
# > 4. How to evaluate with AUC-ROC rather than accuracy (which can be misleading).
# > 5. How to visualize confusion matrices and sample light curves with predictions.

# %% [markdown]
# ## 1. Prerequisites & Data
#
# **Dependencies** (install if needed):
#
# ```bash
# pip install numpy pandas scikit-learn matplotlib tensorflow
# ```
#
# > We intentionally avoid additional plotting libraries to keep dependencies compact.
# > If you already have a working scientific Python/TensorFlow stack, you can skip installations.
#
# **Expected dataset**: a CSV file named **`tess_data.csv`** in the working directory with:
#
# - **Light-curve samples**: `flux_0000, flux_0001, ..., flux_0999` (or up to `n_bins-1`)
# - **Flux uncertainties**: `flux_err_0000, ..., flux_err_0999`
# - **Label**: `label` (0 = Non-Planet, 1 = Planet)
# - **Metadata** (used for plots/titles): `toi_name, tic, disp, period_d, t0_bjd, dur_hr, sector`
#
# You can change the filename or number of bins via parameters in the **Data Loading** section.

# %% [markdown]
# ## 2. Environment Setup
#
# Set up imports, suppress noisy warnings, and fix seeds for reproducibility.
# (Exact reproducibility on GPUs may still vary across hardware/driver versions.)

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try:
    import IPython
    working_directory = "/".join(
            IPython.extract_module_locals()[1]["__vsc_ipynb_file__"].split("/")[:-1]
        )
    print("Setting working directory to: ", working_directory)
    print(os.chdir(working_directory))
except Exception as e:
    print("It was impossible to set your directory as the current one because of the following message")
    print(e)
    print("The working directory is: ", os.getcwd())

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import tensorflow.keras.backend as K

# Reproducibility
np.random.seed(27)
tf.random.set_seed(27)

print("="*70)
print("FINAL TESS CLASSIFICATION")
print("="*70)

# Optional: make TF less eager to pre-allocate all GPU memory (if using GPU)
try:
    gpus = tf.config.experimental.list_physical_devices('GPU')
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    if gpus:
        print(f"Enabled memory growth for {len(gpus)} GPU(s).")
except Exception as e:
    print("GPU setup note:", e)

print("TF version:", tf.__version__)
# Out:
# Setting working directory to:  /ca25/comp_astro25
# None
# 2025-11-29 09:43:35.704196: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-29 09:43:36.843460: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-29 09:43:40.804624: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ======================================================================
# FINAL TESS CLASSIFICATION
# ======================================================================
# TF version: 2.20.0
# 2025-11-29 09:43:41.740832: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# ## 3. Focal Loss (for severe imbalance)
#
# **Why focal loss?** With extreme imbalance, the model can get “lazy”—it learns to do well by focusing on the majority class.
# Focal loss down-weights *easy* examples and concentrates gradient on *hard* ones by adding a modulating factor \((1 - p_t)^\gamma\).
# We also use class weighting via \(\alpha\) to up-weight the rare positive class.
#
# - **`gamma`** (focusing parameter): higher values put more emphasis on hard examples.
# - **`alpha`** (class weight): weight for positive class (1); negative class gets \(1 - \alpha\).

# %%
def focal_loss(gamma=2.5, alpha=0.75):
    """Focal loss optimized for severe imbalance (binary)."""
    def focal_loss_fixed(y_true, y_pred):
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)

        pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
        alpha_factor = tf.where(tf.equal(y_true, 1), alpha, 1 - alpha)
        focal_weight = alpha_factor * K.pow(1 - pt, gamma)
        bce = -K.log(pt)
        return K.mean(focal_weight * bce)
    return focal_loss_fixed

# %% [markdown]
# ## 4. Balanced Augmentation
#
# We **balance the training set** to a fixed number of samples per class.
# If a class has too few samples, we create augmented variants (noise, scale, shift, combo).
# This prevents the model from being swamped by the majority class during training.

# %%
def create_balanced_dataset(X, y, samples_per_class=400):
    """Create a perfectly balanced dataset via lightweight augmentations."""
    print("\n" + "="*70)
    print("CREATING BALANCED DATASET")
    print("="*70)

    X_class0 = X[y == 0]
    X_class1 = X[y == 1]

    print(f"Original - Class 0: {len(X_class0)}, Class 1: {len(X_class1)}")

    def augment_to_target(X_orig, n_target):
        if len(X_orig) >= n_target:
            idx = np.random.choice(len(X_orig), n_target, replace=False)
            return X_orig[idx]

        X_result = [X_orig]
        while len(np.vstack(X_result)) < n_target:
            # number we still need (cap to avoid oversampling too big chunks)
            n_needed = n_target - len(np.vstack(X_result))
            idx = np.random.choice(len(X_orig), min(len(X_orig), n_needed))

            aug_type = np.random.rand()
            if aug_type < 0.25:
                # Additive Gaussian noise
                X_aug = X_orig[idx] + np.random.normal(0, 0.01, (len(idx), X_orig.shape[1]))
            elif aug_type < 0.5:
                # Multiplicative scaling
                scale = 1.0 + np.random.uniform(-0.03, 0.03, (len(idx), 1))
                X_aug = X_orig[idx] * scale
            elif aug_type < 0.75:
                # Circular shift (time shift)
                shifts = np.random.randint(-20, 20, len(idx))
                X_aug = np.array([np.roll(X_orig[i], s) for i, s in zip(idx, shifts)])
            else:
                # Mild combo: small scale + small noise
                X_aug = X_orig[idx] * (1.0 + np.random.uniform(-0.02, 0.02, (len(idx), 1)))
                X_aug += np.random.normal(0, 0.008, X_aug.shape)

            X_result.append(X_aug)

        X_final = np.vstack(X_result)
        return X_final[:n_target]

    X0_bal = augment_to_target(X_class0, samples_per_class)
    X1_bal = augment_to_target(X_class1, samples_per_class)

    print(f"Balanced - Class 0: {len(X0_bal)}, Class 1: {len(X1_bal)}")

    X_balanced = np.vstack([X0_bal, X1_bal])
    y_balanced = np.concatenate([np.zeros(samples_per_class), np.ones(samples_per_class)])

    # Shuffle
    idx = np.arange(len(X_balanced))
    np.random.shuffle(idx)

    return X_balanced[idx], y_balanced[idx]

# %% [markdown]
# ## 5. Data Loading, Splitting & Standardization
#
# We split **before** augmentation (to avoid leakage), then **balance only the training split**.
# We standardize the flux (zero mean / unit variance) using statistics from the training set only.
#
# **Notes**
#
# - Error bars `X_err` are **not** standardized (kept in their original scale).
# - We keep the **test metadata** to produce nicer titles in the sample light-curve plots.

# %%
def load_data(csv_path='tess_data.csv', n_bins=1000):
    """Load CSV, split, balance train set, and standardize features."""
    print("\n" + "="*70)
    print("LOADING DATA")
    print("="*70)

    df = pd.read_csv(csv_path)
    print(f"Dataset: {df.shape[0]} samples")

    flux_cols = [f'flux_{i:04d}' for i in range(n_bins)]
    flux_err_cols = [f'flux_err_{i:04d}' for i in range(n_bins)]
    X = df[flux_cols].values
    X_err = df[flux_err_cols].values
    y = df['label'].values

    metadata_cols = ['toi_name', 'tic', 'label', 'disp', 'period_d', 't0_bjd', 'dur_hr', 'sector']
    metadata = df[metadata_cols]

    print("\nOriginal distribution:")
    print(f"  Class 0: {(y==0).sum()}, Class 1: {(y==1).sum()}")
    if (y==0).sum() > 0:
        print(f"  Ratio: {(y==1).sum() / (y==0).sum():.2f}:1")

    # Train/test split (keep errors aligned; stratify to preserve class ratio)
    X_train, X_test, y_train, y_test, X_err_train, X_err_test, idx_train, idx_test = train_test_split(
        X, y, X_err, np.arange(len(y)),
        test_size=0.2,
        random_state=42,
        stratify=y
    )

    print(f"\nInitial split - Train: {len(X_train)}, Test: {len(X_test)}")

    # Balance training set
    X_train, y_train = create_balanced_dataset(X_train, y_train, samples_per_class=350)

    # Standardize (fit on train, apply to test)
    print("\n" + "="*70)
    print("STANDARDIZATION")
    print("="*70)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    print(f"Train: mean={X_train.mean():.6f}, std={X_train.std():.6f}")
    print(f"Test:  mean={X_test.mean():.6f}, std={X_test.std():.6f}")

    # Reshape for Conv1D: (samples, timesteps, channels)
    X_train = X_train.reshape(-1, n_bins, 1)
    X_test = X_test.reshape(-1, n_bins, 1)

    metadata_test = metadata.iloc[idx_test].reset_index(drop=True)

    print(f"\nFinal - X_train: {X_train.shape}, X_test: {X_test.shape}")
    print(f"Train dist: 0={( y_train==0).sum()}, 1={(y_train==1).sum()}")

    # Return standardized test for model input, but also return the standardized
    # copy (X_test_orig) so we can inverse-transform for plotting with error bars.
    return X_train, X_test, y_train, y_test, metadata_test, X_test.copy(), X_err_test, scaler

# %% [markdown]
# ## 6. A Simpler 1D CNN (to curb overfitting)
#
# A compact ConvNet with **BatchNorm**, **Dropout**, and **Global Average Pooling** is often enough for
# noisy, small-ish 1D signals. We also add mild L2 on the dense layers. The goal is a strong baseline
# that generalizes well, not a gigantic model that memorizes.

# %%
def build_simple_cnn(n_bins=1000):
    """Simpler CNN to prevent overfitting on small datasets."""
    print("\n" + "="*70)
    print("BUILDING SIMPLIFIED CNN")
    print("="*70)

    model = models.Sequential([
        layers.Input(shape=(n_bins, 1)),

        # Feature extraction
        layers.Conv1D(64, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(2),
        layers.Dropout(0.3),

        layers.Conv1D(128, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(2),
        layers.Dropout(0.3),

        layers.Conv1D(256, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.GlobalAveragePooling1D(),
        layers.Dropout(0.4),

        # Classification head
        layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),
        layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),
        layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),

        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0005),
        loss=focal_loss(gamma=2.5, alpha=0.75),
        metrics=['accuracy',
                 keras.metrics.Precision(name='precision'),
                 keras.metrics.Recall(name='recall'),
                 keras.metrics.AUC(name='auc')]
    )

    model.summary()
    print("\nUsing Focal Loss (gamma=2.5, alpha=0.75)")
    return model

# %% [markdown]
# ## 7. Training with AUC Monitoring, Early Stopping & LR Scheduling
#
# We monitor **validation AUC** (not accuracy) and:
#
# - **EarlyStopping** on `val_auc` with patience to stop when progress stalls.
# - **ReduceLROnPlateau** to gently lower the LR when AUC plateaus.
# - **ModelCheckpoint** to persist the best model by AUC.
#
# > Tip: If your dataset is *very* small, increase dropout and/or reduce dense layers further.

# %%
def build_simple_cnn(n_bins=1000):
    """Simpler CNN to prevent overfitting on small datasets."""
    print("\n" + "="*70)
    print("BUILDING SIMPLIFIED CNN")
    print("="*70)

    model = models.Sequential([
        layers.Input(shape=(n_bins, 1)),

        # Feature extraction
        layers.Conv1D(64, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(2),
        layers.Dropout(0.4),

        layers.Conv1D(128, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(2),
        layers.Dropout(0.4),

        layers.Conv1D(256, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(2),
        layers.Dropout(0.5),

        layers.Conv1D(512, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.GlobalAveragePooling1D(),
        layers.Dropout(0.5),

        # Classification head
        layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),
        layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),
        layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),

        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0003),
        loss=focal_loss(gamma=2.5, alpha=0.75),
        metrics=['accuracy',
                 keras.metrics.Precision(name='precision'),
                 keras.metrics.Recall(name='recall'),
                 keras.metrics.AUC(name='auc')]
    )

    model.summary()
    print("\nUsing Focal Loss (gamma=2.5, alpha=0.75)")
    return model

# %%
def train_model(model, X_train, y_train, X_val, y_val, epochs=100):
    """Train the model with AUC-centric callbacks."""
    print("\n" + "="*70)
    print("TRAINING")
    print("="*70)

    # Directory OUTSIDE this notebook
    results_dir = "../assignment2_taskF_results"
    os.makedirs(results_dir, exist_ok=True)

    callbacks = [
        EarlyStopping(
            monitor='val_auc',
            patience=20,
            restore_best_weights=True,
            mode='max',
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_auc',
            factor=0.5,
            patience=8,
            min_lr=1e-7,
            mode='max',
            verbose=1
        ),
        ModelCheckpoint(
            os.path.join(results_dir, 'best_model_final.keras'),
            monitor='val_auc',
            save_best_only=True,
            mode='max',
            verbose=1
        )
    ]

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=32,
        callbacks=callbacks,
        verbose=1
    )
    return history

# %% [markdown]
# ## 8. Evaluation with **Optimal Threshold** (don’t default to 0.5)
#
# The default threshold (0.5) is rarely optimal with imbalanced data.
# We compute ROC, then choose the threshold that maximizes **Youden’s J** (\(\mathrm{TPR} - \mathrm{FPR}\)).
# We report both the default and the optimal settings.

# %%
def evaluate_with_optimal_threshold(model, X_test, y_test):
    """Find an optimal threshold from ROC (Youden's J) and evaluate."""
    print("\n" + "="*70)
    print("THRESHOLD OPTIMIZATION & EVALUATION")
    print("="*70)

    y_pred_proba = model.predict(X_test, verbose=0).flatten()
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

    # Youden's J statistic
    j_scores = tpr - fpr
    optimal_idx = np.argmax(j_scores)
    optimal_threshold = thresholds[optimal_idx]

    print(f"\nOptimal threshold: {optimal_threshold:.4f} (default=0.5)")
    print(f"  At this threshold: TPR={tpr[optimal_idx]:.4f}, FPR={fpr[optimal_idx]:.4f}")

    # Predictions with optimal vs default thresholds
    y_pred_optimal = (y_pred_proba >= optimal_threshold).astype(int)
    y_pred_default = (y_pred_proba >= 0.5).astype(int)

    # Metrics
    acc_optimal = accuracy_score(y_test, y_pred_optimal)
    acc_default = accuracy_score(y_test, y_pred_default)
    auc = roc_auc_score(y_test, y_pred_proba)

    print("\nResults:")
    print(f"  AUC-ROC: {auc:.4f}")
    print(f"  Accuracy (default threshold=0.5): {acc_default:.4f} ({acc_default*100:.2f}%)")
    print(f"  Accuracy (optimal threshold={optimal_threshold:.4f}): {acc_optimal:.4f} ({acc_optimal*100:.2f}%)")

    print("\nWith optimal threshold:")
    print(classification_report(y_test, y_pred_optimal,
                                target_names=['Non-Planet', 'Planet'],
                                digits=4,
                                zero_division=0))

    print("\nPrediction distribution (optimal threshold):")
    print(f"  Predicted 0: {(y_pred_optimal == 0).sum()}")
    print(f"  Predicted 1: {(y_pred_optimal == 1).sum()}")
    print("True distribution:")
    print(f"  True 0: {(y_test == 0).sum()}")
    print(f"  True 1: {(y_test == 1).sum()}")

    return y_pred_optimal, y_pred_proba, optimal_threshold

# %% [markdown]
# ## 9. Visualization (Matplotlib-only)
#
# We save:
# - **Confusion matrix** (`confusion_matrix_final.png`) with counts and percentages.
# - **Training curves** (`training_history_final.png`).
# - **Sample light curves with predictions** (`sample_lightcurves_predictions.png`).
#
# > We use **Matplotlib** exclusively to minimize dependencies.

# %%
import os

def plot_lightcurves_with_predictions(X_test_orig, X_err_test, y_test, y_pred, y_pred_proba,
                                      metadata_test, scaler, threshold, n_samples=6,
                                      save_path=None):
    """Plot light curves with error bars and prediction info; save to file."""

    # Create results directory
    results_dir = "../assignment2_taskF_results"
    os.makedirs(results_dir, exist_ok=True)

    if save_path is None:
        save_path = os.path.join(results_dir, "sample_lightcurves_predictions.png")

    print("\n" + "="*70)
    print(f"PLOTTING LIGHTCURVES WITH PREDICTIONS (n={n_samples})")
    print("="*70)

    n_samples = min(n_samples, len(X_test_orig))

    # Select diverse samples: correct/incorrect for both classes
    correct_planet = np.where((y_test == 1) & (y_pred == 1))[0]
    incorrect_planet = np.where((y_test == 1) & (y_pred == 0))[0]
    correct_nonplanet = np.where((y_test == 0) & (y_pred == 0))[0]
    incorrect_nonplanet = np.where((y_test == 0) & (y_pred == 1))[0]

    selected_idx = []
    per_category = max(1, n_samples // 4)

    for idx_list in [correct_planet, incorrect_planet, correct_nonplanet, incorrect_nonplanet]:
        if len(idx_list) > 0:
            n_select = min(per_category, len(idx_list))
            selected_idx.extend(np.random.choice(idx_list, n_select, replace=False))

    while len(selected_idx) < n_samples:
        remaining = list(set(range(len(y_test))) - set(selected_idx))
        if remaining:
            selected_idx.append(np.random.choice(remaining))
        else:
            break

    selected_idx = np.array(selected_idx[:n_samples])

    # Figure layout
    n_cols = 2
    n_rows = (n_samples + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 4*n_rows))
    if n_samples == 1:
        axes = np.array([axes])
    axes = axes.flatten()

    for plot_i, idx in enumerate(selected_idx):
        ax = axes[plot_i]

        flux_norm = X_test_orig[idx].flatten()
        flux_err = X_err_test[idx]
        flux_original = scaler.inverse_transform(flux_norm.reshape(1, -1)).flatten()

        time_bins = np.arange(len(flux_original))

        # Metadata
        toi_name = metadata_test.loc[idx, 'toi_name']
        tic = metadata_test.loc[idx, 'tic']
        disp = metadata_test.loc[idx, 'disp']
        sector = metadata_test.loc[idx, 'sector']

        true_label = y_test[idx]
        pred_label = y_pred[idx]
        pred_prob = y_pred_proba[idx]

        is_correct = (true_label == pred_label)
        true_str = 'Transit' if true_label == 1 else 'Non-Transit'
        pred_str = 'Transit' if pred_label == 1 else 'Non-Transit'

        ax.errorbar(time_bins, flux_original, yerr=flux_err, fmt='o', markersize=2,
                    ecolor='gray', elinewidth=0.5, capsize=0, alpha=0.6, label='Data')

        baseline = np.median(flux_original)
        ax.axhline(baseline, linestyle='--', linewidth=1, alpha=0.7, label='Baseline')

        ax.set_xlabel('Time Bin', fontsize=10, fontweight='bold')
        ax.set_ylabel('Flux (original scale)', fontsize=10, fontweight='bold')
        ax.grid(True, alpha=0.3)
        ax.legend(loc='upper right', fontsize=8)

        status_symbol = '✓' if is_correct else '✗'
        color = 'green' if is_correct else 'red'
        title = (f'TOI {toi_name} (TIC {tic}, {disp}) - TESS Sector {sector}\n'
                 f'True: {true_str} | Pred: {pred_str} (p={pred_prob:.3f}) {status_symbol}')
        ax.set_title(title, fontsize=10, fontweight='bold', color=color, pad=10)

        for spine in ax.spines.values():
            spine.set_edgecolor(color)
            spine.set_linewidth(2.0)

    for j in range(n_samples, len(axes)):
        axes[j].axis('off')

    plt.suptitle(f'Sample Light-curve Predictions (Threshold={threshold:.3f})',
                 fontsize=14, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"Saved: {save_path}")
    plt.close()


def plot_all(y_test, y_pred, y_pred_proba, history, metadata_test, X_test, threshold,
             X_test_orig=None, X_err_test=None, scaler=None):

    print("\n" + "="*70)
    print("VISUALIZATIONS")
    print("="*70)

    # Directory for results
    results_dir = "../assignment2_taskF_results"
    os.makedirs(results_dir, exist_ok=True)

    # --- Confusion matrix ---
    cm = confusion_matrix(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(8, 6))
    im = ax.imshow(cm, interpolation='nearest', cmap='Blues')
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(2),
           yticks=np.arange(2),
           xticklabels=['Non-Planet', 'Planet'],
           yticklabels=['Non-Planet', 'Planet'],
           xlabel='Predicted', ylabel='True',
           title=f'Confusion Matrix (threshold={threshold:.3f})')

    total = cm.sum()
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            count = cm[i, j]
            pct = (count / total * 100) if total > 0 else 0.0
            ax.text(j, i, f"{count}\n({pct:.1f}%)", ha='center', va='center', color='black', fontsize=10)

    plt.tight_layout()
    cm_path = os.path.join(results_dir, 'confusion_matrix_final.png')
    plt.savefig(cm_path, dpi=300)
    print(f"Saved: {cm_path}")
    plt.close()

    # --- Training history ---
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    metrics = [('loss', 'Loss'), ('accuracy', 'Accuracy'),
               ('auc', 'AUC'), ('recall', 'Recall')]

    for idx, (metric, title) in enumerate(metrics):
        ax = axes[idx // 2, idx % 2]
        if metric in history.history and f'val_{metric}' in history.history:
            ax.plot(history.history[metric], label='Train', linewidth=2)
            ax.plot(history.history[f'val_{metric}'], label='Val', linewidth=2)
            ax.set_xlabel('Epoch')
            ax.set_ylabel(title)
            ax.set_title(f'{title} vs Epoch', fontweight='bold')
            ax.legend()
            ax.grid(alpha=0.3)

    plt.suptitle('Training History - Final Model', fontsize=14, fontweight='bold')
    plt.tight_layout()
    hist_path = os.path.join(results_dir, 'training_history_final.png')
    plt.savefig(hist_path, dpi=300)
    print(f"Saved: {hist_path}")
    plt.close()

    # --- Light curves ---
    if X_test_orig is not None and X_err_test is not None and scaler is not None:
        plot_lightcurves_with_predictions(
            X_test_orig, X_err_test, y_test, y_pred,
            y_pred_proba, metadata_test, scaler, threshold,
            n_samples=6,
            save_path=os.path.join(results_dir, "sample_lightcurves_predictions.png")
        )

# %% [markdown]
# ## 10. Run the Pipeline
#
# You can run the following cells **step by step**, or use the **end-to-end** cell.
#
# > If your CSV isn’t called `tess_data.csv`, change `CSV_PATH` below.

# %%
# Path to your dataset
CSV_PATH = 'tess_data.csv'   # <- change me if needed
N_BINS = 1000                # number of flux bins/columns per sample

# %%
# 1) Load and prepare data
X_train, X_test, y_train, y_test, metadata_test, X_test_orig, X_err_test, scaler = load_data(
    csv_path=CSV_PATH, n_bins=N_BINS
)
# Out:
# ======================================================================
# LOADING DATA
# ======================================================================
# Dataset: 944 samples
#
# Original distribution:
#   Class 0: 472, Class 1: 472
#   Ratio: 1.00:1
#
# Initial split - Train: 755, Test: 189
#
# ======================================================================
# CREATING BALANCED DATASET
# ======================================================================
# Original - Class 0: 377, Class 1: 378
# Balanced - Class 0: 350, Class 1: 350
#
# ======================================================================
# STANDARDIZATION
# ======================================================================
# Train: mean=-0.000000, std=1.000000
# Test:  mean=-0.000731, std=0.428543
#
# Final - X_train: (700, 1000, 1), X_test: (189, 1000, 1)
# Train dist: 0=350, 1=350

# %%
# 2) Build model
model = build_simple_cnn(n_bins=N_BINS)
# Out:
# ======================================================================
# BUILDING SIMPLIFIED CNN
# ======================================================================
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_20 (Conv1D)              │ (None, 1000, 64)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 1000, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_15 (MaxPooling1D) │ (None, 500, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_35 (Dropout)            │ (None, 500, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_21 (Conv1D)              │ (None, 500, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 500, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_16 (MaxPooling1D) │ (None, 250, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_36 (Dropout)            │ (None, 250, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_22 (Conv1D)              │ (None, 250, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 250, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_17 (MaxPooling1D) │ (None, 125, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_37 (Dropout)            │ (None, 125, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_23 (Conv1D)              │ (None, 125, 512)       │       393,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 125, 512)       │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_5      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_38 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_39 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_40 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_41 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 948,097 (3.62 MB)
#  Trainable params: 946,177 (3.61 MB)
#  Non-trainable params: 1,920 (7.50 KB)
# Using Focal Loss (gamma=2.5, alpha=0.75)

# %%
# 3) Train
history = train_model(model, X_train, y_train, X_test, y_test, epochs=200)
# Out:
# ======================================================================
# TRAINING
# ======================================================================
# Epoch 1/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5373 - auc: 0.4873 - loss: 1.0600 - precision: 0.5414 - recall: 0.8020
# Epoch 1: val_auc improved from None to 0.54211, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 288ms/step - accuracy: 0.5186 - auc: 0.4539 - loss: 1.0332 - precision: 0.5104 - recall: 0.9114 - val_accuracy: 0.4974 - val_auc: 0.5421 - val_loss: 0.9796 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 3.0000e-04
# Epoch 2/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.5272 - auc: 0.4887 - loss: 0.9667 - precision: 0.5233 - recall: 0.9558
# Epoch 2: val_auc did not improve from 0.54211
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.5143 - auc: 0.4929 - loss: 0.9507 - precision: 0.5075 - recall: 0.9657 - val_accuracy: 0.4974 - val_auc: 0.5151 - val_loss: 0.9044 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 3.0000e-04
# Epoch 3/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.5272 - auc: 0.5878 - loss: 0.8905 - precision: 0.5229 - recall: 0.9668
# Epoch 3: val_auc improved from 0.54211 to 0.67850, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s
val_auc did not improve from 0.74597
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.6900 - auc: 0.7943 - loss: 0.2955 - precision: 0.6301 - recall: 0.9200 - val_accuracy: 0.4974 - val_auc: 0.5933 - val_loss: 0.3265 - val_precision: 0.3333 - val_recall: 0.0106 - learning_rate: 1.5000e-04
# Epoch 23/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6985 - auc: 0.8144 - loss: 0.2875 - precision: 0.6439 - recall: 0.9318
# Epoch 23: val_auc did not improve from 0.74597
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - accuracy: 0.6814 - auc: 0.8076 - loss: 0.2859 - precision: 0.6219 - recall: 0.9257 - val_accuracy: 0.5344 - val_auc: 0.5591 - val_loss: 0.3084 - val_precision: 0.8000 - val_recall: 0.0851 - learning_rate: 1.5000e-04
# Epoch 24/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.6974 - auc: 0.7973 - loss: 0.2805 - precision: 0.6467 - recall: 0.9133
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 24: val_auc did not improve from 0.74597
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.6757 - auc: 0.7962 - loss: 0.2777 - precision: 0.6176 - recall: 0.9229 - val_accuracy: 0.5503 - val_auc: 0.5880 - val_loss: 0.2858 - val_precision: 0.5287 - val_recall: 0.8830 - learning_rate: 1.5000e-04
# Epoch 25/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6611 - auc: 0.8116 - loss: 0.2708 - precision: 0.6104 - recall: 0.9508
# Epoch 25: val_auc did not improve from 0.74597
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.6586 - auc: 0.8134 - loss: 0.2697 - precision: 0.6011 - recall: 0.9429 - val_accuracy: 0.5450 - val_auc: 0.5910 - val_loss: 0.2786 - val_precision: 0.5247 - val_recall: 0.9043 - learning_rate: 7.5000e-05
# Epoch 26/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7011 - auc: 0.7978 - loss: 0.2668 - precision: 0.6459 - recall: 0.9337
# Epoch 26: val_auc improved from 0.74597 to 0.78242, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 194ms/step - accuracy: 0.6857 - auc: 0.8004 - loss: 0.2660 - precision: 0.6260 - recall: 0.9229 - val_accuracy: 0.6349 - val_auc: 0.7824 - val_loss: 0.2746 - val_precision: 0.5912 - val_recall: 0.8617 - learning_rate: 7.5000e-05
# Epoch 27/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7112 - auc: 0.8095 - loss: 0.2618 - precision: 0.6546 - recall: 0.9337
# Epoch 27: val_auc did not improve from 0.78242
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.7000 - auc: 0.8092 - loss: 0.2610 - precision: 0.6362 - recall: 0.9343 - val_accuracy: 0.5503 - val_auc: 0.7325 - val_loss: 0.2669 - val_precision: 0.5280 - val_recall: 0.9043 - learning_rate: 7.5000e-05
# Epoch 28/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6548 - auc: 0.7877 - loss: 0.2592 - precision: 0.6129 - recall: 0.8997
# Epoch 28: val_auc improved from 0.78242 to 0.84608, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - accuracy: 0.6786 - auc: 0.8047 - loss: 0.2573 - precision: 0.6204 - recall: 0.9200 - val_accuracy: 0.7937 - val_auc: 0.8461 - val_loss: 0.2657 - val_precision: 0.8313 - val_recall: 0.7340 - learning_rate: 7.5000e-05
# Epoch 29/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6852 - auc: 0.8060 - loss: 0.2540 - precision: 0.6367 - recall: 0.9101
# Epoch 29: val_auc did not improve from 0.84608
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.6843 - auc: 0.8167 - loss: 0.2524 - precision: 0.6262 - recall: 0.9143 - val_accuracy: 0.7513 - val_auc: 0.8368 - val_loss: 0.2581 - val_precision: 0.7117 - val_recall: 0.8404 - learning_rate: 7.5000e-05
# Epoch 30/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6973 - auc: 0.8026 - loss: 0.2523 - precision: 0.6451 - recall: 0.9223
# Epoch 30: val_auc improved from 0.84608 to 0.85297, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - accuracy: 0.6957 - auc: 0.8168 - loss: 0.2485 - precision: 0.6315 - recall: 0.9400 - val_accuracy: 0.8042 - val_auc: 0.8530 - val_loss: 0.2543 - val_precision: 0.8202 - val_recall: 0.7766 - learning_rate: 7.5000e-05
# Epoch 31/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7204 - auc: 0.8197 - loss: 0.2446 - precision: 0.6655 - recall: 0.9221
# Epoch 31: val_auc improved from 0.85297 to 0.87100, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.7071 - auc: 0.8151 - loss: 0.2441 - precision: 0.6483 - recall: 0.9057 - val_accuracy: 0.8148 - val_auc: 0.8710 - val_loss: 0.2449 - val_precision: 0.7864 - val_recall: 0.8617 - learning_rate: 7.5000e-05
# Epoch 32/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.7268 - auc: 0.8260 - loss: 0.2397 - precision: 0.6680 - recall: 0.9376
# Epoch 32: val_auc improved from 0.87100 to 0.87172, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 193ms/step - accuracy: 0.7200 - auc: 0.8193 - loss: 0.2395 - precision: 0.6528 - recall: 0.9400 - val_accuracy: 0.7884 - val_auc: 0.8717 - val_loss: 0.2384 - val_precision: 0.7288 - val_recall: 0.9149 - learning_rate: 7.5000e-05
# Epoch 33/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7109 - auc: 0.8148 - loss: 0.2370 - precision: 0.6556 - recall: 0.9284
# Epoch 33: val_auc improved from 0.87172 to 0.88219, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 223ms/step - accuracy: 0.6986 - auc: 0.8156 - loss: 0.2360 - precision: 0.6355 - recall: 0.9314 - val_accuracy: 0.8201 - val_auc: 0.8822 - val_loss: 0.2341 - val_precision: 0.7941 - val_recall: 0.8617 - learning_rate: 7.5000e-05
# Epoch 34/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7142 - auc: 0.8000 - loss: 0.2333 - precision: 0.6599 - recall: 0.9214
# Epoch 34: val_auc did not improve from 0.88219
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.7000 - auc: 0.8005 - loss: 0.2329 - precision: 0.6394 - recall: 0.9171 - val_accuracy: 0.5767 - val_auc: 0.8531 - val_loss: 0.2299 - val_precision: 0.5427 - val_recall: 0.9468 - learning_rate: 7.5000e-05
# Epoch 35/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6941 - auc: 0.8171 - loss: 0.2282 - precision: 0.6355 - recall: 0.9558
# Epoch 35: val_auc improved from 0.88219 to 0.88723, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.6900 - auc: 0.8136 - loss: 0.2279 - precision: 0.6262 - recall: 0.9429 - val_accuracy: 0.8254 - val_auc: 0.8872 - val_loss: 0.2261 - val_precision: 0.8211 - val_recall: 0.8298 - learning_rate: 7.5000e-05
# Epoch 36/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7339 - auc: 0.8162 - loss: 0.2246 - precision: 0.6738 - recall: 0.9399
# Epoch 36: val_auc did not improve from 0.88723
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.7129 - auc: 0.8111 - loss: 0.2241 - precision: 0.6475 - recall: 0.9343 - val_accuracy: 0.5714 - val_auc: 0.8553 - val_loss: 0.2221 - val_precision: 0.5389 - val_recall: 0.9574 - learning_rate: 7.5000e-05
# Epoch 37/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6979 - auc: 0.8234 - loss: 0.2205 - precision: 0.6431 - recall: 0.9344
# Epoch 37: val_auc did not improve from 0.88723
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.7143 - auc: 0.8255 - loss: 0.2196 - precision: 0.6512 - recall: 0.9229 - val_accuracy: 0.7672 - val_auc: 0.8852 - val_loss: 0.2154 - val_precision: 0.6984 - val_recall: 0.9362 - learning_rate: 7.5000e-05
# Epoch 38/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7169 - auc: 0.8024 - loss: 0.2188 - precision: 0.6568 - recall: 0.9511
# Epoch 38: val_auc did not improve from 0.88723
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.6914 - auc: 0.8073 - loss: 0.2173 - precision: 0.6279 - recall: 0.9400 - val_accuracy: 0.8042 - val_auc: 0.8871 - val_loss: 0.2174 - val_precision: 0.8434 - val_recall: 0.7447 - learning_rate: 7.5000e-05
# Epoch 39/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7060 - auc: 0.8167 - loss: 0.2136 - precision: 0.6552 - recall: 0.9095
# Epoch 39: val_auc did not improve from 0.88723
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.6857 - auc: 0.8131 - loss: 0.2130 - precision: 0.6280 - recall: 0.9114 - val_accuracy: 0.8413 - val_auc: 0.8832 - val_loss: 0.2117 - val_precision: 0.8333 - val_recall: 0.8511 - learning_rate: 7.5000e-05
# Epoch 40/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7010 - auc: 0.8176 - loss: 0.2099 - precision: 0.6454 - recall: 0.9368
# Epoch 40: val_auc did not improve from 0.88723
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.6871 - auc: 0.8161 - loss: 0.2092 - precision: 0.6262 - recall: 0.9286 - val_accuracy: 0.7778 - val_auc: 0.8848 - val_loss: 0.2151 - val_precision: 0.8611 - val_recall: 0.6596 - learning_rate: 7.5000e-05
# Epoch 41/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7370 - auc: 0.8340 - loss: 0.2044 - precision: 0.6765 - recall: 0.9413
# Epoch 41: val_auc did not improve from 0.88723
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.7286 - auc: 0.8375 - loss: 0.2037 - precision: 0.6653 - recall: 0.9200 - val_accuracy: 0.7672 - val_auc: 0.8848 - val_loss: 0.2144 - val_precision: 0.8676 - val_recall: 0.6277 - learning_rate: 7.5000e-05
# Epoch 42/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7294 - auc: 0.8234 - loss: 0.2023 - precision: 0.6707 - recall: 0.9366
# Epoch 42: val_auc did not improve from 0.88723
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.7057 - auc: 0.8188 - loss: 0.2019 - precision: 0.6429 - recall: 0.9257 - val_accuracy: 0.8307 - val_auc: 0.8846 - val_loss: 0.2021 - val_precision: 0.8444 - val_recall: 0.8085 - learning_rate: 7.5000e-05
# Epoch 43/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7200 - auc: 0.8240 - loss: 0.1981 - precision: 0.6624 - recall: 0.9348
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
#
# Epoch 43: val_auc did not improve from 0.88723
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.7086 - auc: 0.8282 - loss: 0.1972 - precision: 0.6454 - recall: 0.9257 - val_accuracy: 0.7672 - val_auc: 0.8856 - val_loss: 0.2088 - val_precision: 0.8676 - val_recall: 0.6277 - learning_rate: 7.5000e-05
# Epoch 44/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7249 - auc: 0.8238 - loss: 0.1952 - precision: 0.6656 - recall: 0.9420
# Epoch 44: val_auc improved from 0.88723 to 0.89143, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.7114 - auc: 0.8305 - loss: 0.1946 - precision: 0.6474 - recall: 0.9286 - val_accuracy: 0.7672 - val_auc: 0.8914 - val_loss: 0.2053 - val_precision: 0.8676 - val_recall: 0.6277 - learning_rate: 3.7500e-05
# Epoch 45/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7343 - auc: 0.8206 - loss: 0.1934 - precision: 0.6771 - recall: 0.9317
# Epoch 45: val_auc improved from 0.89143 to 0.89608, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.7071 - auc: 0.8192 - loss: 0.1938 - precision: 0.6459 - recall: 0.9171 - val_accuracy: 0.7672 - val_auc: 0.8961 - val_loss: 0.2009 - val_precision: 0.8676 - val_recall: 0.6277 - learning_rate: 3.7500e-05
# Epoch 46/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7271 - auc: 0.8220 - loss: 0.1918 - precision: 0.6708 - recall: 0.9264
# Epoch 46: val_auc did not improve from 0.89608
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.7200 - auc: 0.8262 - loss: 0.1914 - precision: 0.6571 - recall: 0.9200 - val_accuracy: 0.8254 - val_auc: 0.8914 - val_loss: 0.1931 - val_precision: 0.8675 - val_recall: 0.7660 - learning_rate: 3.7500e-05
# Epoch 47/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7332 - auc: 0.8469 - loss: 0.1886 - precision: 0.6714 - recall: 0.9477
# Epoch 47: val_auc did not improve from 0.89608
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.7143 - auc: 0.8486 - loss: 0.1882 - precision: 0.6482 - recall: 0.9371 - val_accuracy: 0.7407 - val_auc: 0.8888 - val_loss: 0.2063 - val_precision: 0.8689 - val_recall: 0.5638 - learning_rate: 3.7500e-05
# Epoch 48/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7166 - auc: 0.8196 - loss: 0.1886 - precision: 0.6661 - recall: 0.9076
# Epoch 48: val_auc did not improve from 0.89608
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.7086 - auc: 0.8253 - loss: 0.1882 - precision: 0.6496 - recall: 0.9057 - val_accuracy: 0.7513 - val_auc: 0.8911 - val_loss: 0.2021 - val_precision: 0.8730 - val_recall: 0.5851 - learning_rate: 3.7500e-05
# Epoch 49/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7412 - auc: 0.8357 - loss: 0.1854 - precision: 0.6791 - recall: 0.9475
# Epoch 49: val_auc did not improve from 0.89608
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 243ms/step - accuracy: 0.7314 - auc: 0.8407 - loss: 0.1850 - precision: 0.6627 - recall: 0.9429 - val_accuracy: 0.7778 - val_auc: 0.8943 - val_loss: 0.1916 - val_precision: 0.8611 - val_recall: 0.6596 - learning_rate: 3.7500e-05
# Epoch 50/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.7253 - auc: 0.8237 - loss: 0.1853 - precision: 0.6659 - recall: 0.9403
# Epoch 50: val_auc did not improve from 0.89608
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.7200 - auc: 0.8404 - loss: 0.1837 - precision: 0.6528 - recall: 0.9400 - val_accuracy: 0.7566 - val_auc: 0.8934 - val_loss: 0.1965 - val_precision: 0.8636 - val_recall: 0.6064 - learning_rate: 3.7500e-05
# Epoch 51/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.7256 - auc: 0.8230 - loss: 0.1832 - precision: 0.6697 - recall: 0.9271
# Epoch 51: val_auc improved from 0.89608 to 0.89630, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 259ms/step - accuracy: 0.7100 - auc: 0.8193 - loss: 0.1835 - precision: 0.6479 - recall: 0.9200 - val_accuracy: 0.7672 - val_auc: 0.8963 - val_loss: 0.1927 - val_precision: 0.8676 - val_recall: 0.6277 - learning_rate: 3.7500e-05
# Epoch 52/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7169 - auc: 0.8270 - loss: 0.1817 - precision: 0.6585 - recall: 0.9405
# Epoch 52: val_auc improved from 0.89630 to 0.89843, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - accuracy: 0.7243 - auc: 0.8331 - loss: 0.1808 - precision: 0.6561 - recall: 0.9429 - val_accuracy: 0.7831 - val_auc: 0.8984 - val_loss: 0.1851 - val_precision: 0.8630 - val_recall: 0.6702 - learning_rate: 3.7500e-05
# Epoch 53/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.
val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - accuracy: 0.7171 - auc: 0.8259 - loss: 0.1685 - precision: 0.6564 - recall: 0.9114 - val_accuracy: 0.7513 - val_auc: 0.8938 - val_loss: 0.1843 - val_precision: 0.8730 - val_recall: 0.5851 - learning_rate: 3.7500e-05
# Epoch 61/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.7324 - auc: 0.8275 - loss: 0.1660 - precision: 0.6745 - recall: 0.9324
# Epoch 61: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.7243 - auc: 0.8307 - loss: 0.1660 - precision: 0.6599 - recall: 0.9257 - val_accuracy: 0.7460 - val_auc: 0.8947 - val_loss: 0.1857 - val_precision: 0.8833 - val_recall: 0.5638 - learning_rate: 3.7500e-05
# Epoch 62/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7230 - auc: 0.8380 - loss: 0.1644 - precision: 0.6664 - recall: 0.9292
# Epoch 62: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - accuracy: 0.7214 - auc: 0.8447 - loss: 0.1637 - precision: 0.6559 - recall: 0.9314 - val_accuracy: 0.7196 - val_auc: 0.8892 - val_loss: 0.1951 - val_precision: 0.8868 - val_recall: 0.5000 - learning_rate: 3.7500e-05
# Epoch 63/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.7621 - auc: 0.8353 - loss: 0.1631 - precision: 0.7063 - recall: 0.9235
# Epoch 63: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.7414 - auc: 0.8316 - loss: 0.1630 - precision: 0.6786 - recall: 0.9171 - val_accuracy: 0.7513 - val_auc: 0.8956 - val_loss: 0.1773 - val_precision: 0.8730 - val_recall: 0.5851 - learning_rate: 3.7500e-05
# Epoch 64/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7500 - auc: 0.8361 - loss: 0.1610 - precision: 0.6877 - recall: 0.9494
# Epoch 64: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - accuracy: 0.7214 - auc: 0.8313 - loss: 0.1616 - precision: 0.6547 - recall: 0.9371 - val_accuracy: 0.7566 - val_auc: 0.8942 - val_loss: 0.1790 - val_precision: 0.8871 - val_recall: 0.5851 - learning_rate: 3.7500e-05
# Epoch 65/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7158 - auc: 0.8257 - loss: 0.1610 - precision: 0.6625 - recall: 0.9171
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
#
# Epoch 65: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.7200 - auc: 0.8300 - loss: 0.1604 - precision: 0.6578 - recall: 0.9171 - val_accuracy: 0.7884 - val_auc: 0.8970 - val_loss: 0.1659 - val_precision: 0.8750 - val_recall: 0.6702 - learning_rate: 3.7500e-05
# Epoch 66/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7322 - auc: 0.8495 - loss: 0.1571 - precision: 0.6672 - recall: 0.9604
# Epoch 66: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 220ms/step - accuracy: 0.7271 - auc: 0.8452 - loss: 0.1579 - precision: 0.6606 - recall: 0.9343 - val_accuracy: 0.7566 - val_auc: 0.8920 - val_loss: 0.1761 - val_precision: 0.8871 - val_recall: 0.5851 - learning_rate: 1.8750e-05
# Epoch 67/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7461 - auc: 0.8179 - loss: 0.1586 - precision: 0.6858 - recall: 0.9381
# Epoch 67: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.7343 - auc: 0.8325 - loss: 0.1577 - precision: 0.6708 - recall: 0.9200 - val_accuracy: 0.7566 - val_auc: 0.8909 - val_loss: 0.1759 - val_precision: 0.8871 - val_recall: 0.5851 - learning_rate: 1.8750e-05
# Epoch 68/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7381 - auc: 0.8297 - loss: 0.1578 - precision: 0.6829 - recall: 0.9243
# Epoch 68: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - accuracy: 0.7100 - auc: 0.8284 - loss: 0.1576 - precision: 0.6479 - recall: 0.9200 - val_accuracy: 0.7566 - val_auc: 0.8912 - val_loss: 0.1756 - val_precision: 0.8871 - val_recall: 0.5851 - learning_rate: 1.8750e-05
# Epoch 69/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.7460 - auc: 0.8418 - loss: 0.1555 - precision: 0.6900 - recall: 0.9236
# Epoch 69: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.7271 - auc: 0.8384 - loss: 0.1559 - precision: 0.6646 - recall: 0.9171 - val_accuracy: 0.7566 - val_auc: 0.8925 - val_loss: 0.1751 - val_precision: 0.8871 - val_recall: 0.5851 - learning_rate: 1.8750e-05
# Epoch 70/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7265 - auc: 0.8266 - loss: 0.1561 - precision: 0.6722 - recall: 0.9199
# Epoch 70: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.7129 - auc: 0.8270 - loss: 0.1560 - precision: 0.6530 - recall: 0.9086 - val_accuracy: 0.7619 - val_auc: 0.8931 - val_loss: 0.1699 - val_precision: 0.8657 - val_recall: 0.6170 - learning_rate: 1.8750e-05
# Epoch 71/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.6999 - auc: 0.8228 - loss: 0.1559 - precision: 0.6467 - recall: 0.9266
# Epoch 71: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.7014 - auc: 0.8344 - loss: 0.1549 - precision: 0.6385 - recall: 0.9286 - val_accuracy: 0.7407 - val_auc: 0.8913 - val_loss: 0.1767 - val_precision: 0.8814 - val_recall: 0.5532 - learning_rate: 1.8750e-05
# Epoch 72/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7511 - auc: 0.8315 - loss: 0.1536 - precision: 0.6925 - recall: 0.9319
# Epoch 72: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - accuracy: 0.7286 - auc: 0.8363 - loss: 0.1538 - precision: 0.6653 - recall: 0.9200 - val_accuracy: 0.7566 - val_auc: 0.8961 - val_loss: 0.1686 - val_precision: 0.8750 - val_recall: 0.5957 - learning_rate: 1.8750e-05
# Epoch 73/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7199 - auc: 0.8373 - loss: 0.1532 - precision: 0.6687 - recall: 0.9082
# Epoch 73: ReduceLROnPlateau reducing learning rate to 9.375000445288606e-06.
#
# Epoch 73: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - accuracy: 0.7157 - auc: 0.8426 - loss: 0.1525 - precision: 0.6531 - recall: 0.9200 - val_accuracy: 0.7672 - val_auc: 0.8983 - val_loss: 0.1638 - val_precision: 0.8571 - val_recall: 0.6383 - learning_rate: 1.8750e-05
# Epoch 74/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7305 - auc: 0.8387 - loss: 0.1528 - precision: 0.6749 - recall: 0.9226
# Epoch 74: val_auc did not improve from 0.89882
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.7300 - auc: 0.8437 - loss: 0.1519 - precision: 0.6653 - recall: 0.9257 - val_accuracy: 0.7672 - val_auc: 0.8985 - val_loss: 0.1597 - val_precision: 0.8571 - val_recall: 0.6383 - learning_rate: 9.3750e-06
# Epoch 75/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.7177 - auc: 0.8263 - loss: 0.1523 - precision: 0.6644 - recall: 0.9173
# Epoch 75: val_auc improved from 0.89882 to 0.89983, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 237ms/step - accuracy: 0.7214 - auc: 0.8321 - loss: 0.1519 - precision: 0.6559 - recall: 0.9314 - val_accuracy: 0.7672 - val_auc: 0.8998 - val_loss: 0.1586 - val_precision: 0.8571 - val_recall: 0.6383 - learning_rate: 9.3750e-06
# Epoch 76/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.7301 - auc: 0.8148 - loss: 0.1530 - precision: 0.6766 - recall: 0.9165
# Epoch 76: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.7200 - auc: 0.8252 - loss: 0.1523 - precision: 0.6571 - recall: 0.9200 - val_accuracy: 0.7672 - val_auc: 0.8980 - val_loss: 0.1587 - val_precision: 0.8571 - val_recall: 0.6383 - learning_rate: 9.3750e-06
# Epoch 77/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.6980 - auc: 0.8299 - loss: 0.1514 - precision: 0.6471 - recall: 0.9126
# Epoch 77: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.6943 - auc: 0.8391 - loss: 0.1510 - precision: 0.6355 - recall: 0.9114 - val_accuracy: 0.7672 - val_auc: 0.8991 - val_loss: 0.1616 - val_precision: 0.8571 - val_recall: 0.6383 - learning_rate: 9.3750e-06
# Epoch 78/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7284 - auc: 0.8367 - loss: 0.1504 - precision: 0.6708 - recall: 0.9337
# Epoch 78: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.7114 - auc: 0.8382 - loss: 0.1505 - precision: 0.6480 - recall: 0.9257 - val_accuracy: 0.7566 - val_auc: 0.8996 - val_loss: 0.1622 - val_precision: 0.8529 - val_recall: 0.6170 - learning_rate: 9.3750e-06
# Epoch 79/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7430 - auc: 0.8448 - loss: 0.1495 - precision: 0.6836 - recall: 0.9375
# Epoch 79: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - accuracy: 0.7400 - auc: 0.8495 - loss: 0.1492 - precision: 0.6728 - recall: 0.9343 - val_accuracy: 0.7566 - val_auc: 0.8989 - val_loss: 0.1632 - val_precision: 0.8529 - val_recall: 0.6170 - learning_rate: 9.3750e-06
# Epoch 80/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7406 - auc: 0.8345 - loss: 0.1501 - precision: 0.6835 - recall: 0.9265
# Epoch 80: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.7314 - auc: 0.8362 - loss: 0.1500 - precision: 0.6695 - recall: 0.9143 - val_accuracy: 0.7778 - val_auc: 0.8989 - val_loss: 0.1561 - val_precision: 0.8611 - val_recall: 0.6596 - learning_rate: 9.3750e-06
# Epoch 81/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7153 - auc: 0.8232 - loss: 0.1505 - precision: 0.6587 - recall: 0.9318
# Epoch 81: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - accuracy: 0.7171 - auc: 0.8305 - loss: 0.1500 - precision: 0.6520 - recall: 0.9314 - val_accuracy: 0.7725 - val_auc: 0.8986 - val_loss: 0.1569 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 9.3750e-06
# Epoch 82/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7119 - auc: 0.8233 - loss: 0.1500 - precision: 0.6554 - recall: 0.9336
# Epoch 82: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.7071 - auc: 0.8243 - loss: 0.1502 - precision: 0.6441 - recall: 0.9257 - val_accuracy: 0.7725 - val_auc: 0.8978 - val_loss: 0.1583 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 9.3750e-06
# Epoch 83/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7422 - auc: 0.8429 - loss: 0.1481 - precision: 0.6816 - recall: 0.9407
# Epoch 83: ReduceLROnPlateau reducing learning rate to 4.687500222644303e-06.
#
# Epoch 83: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.7357 - auc: 0.8417 - loss: 0.1482 - precision: 0.6680 - recall: 0.9371 - val_accuracy: 0.7725 - val_auc: 0.8976 - val_loss: 0.1563 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 9.3750e-06
# Epoch 84/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7252 - auc: 0.8317 - loss: 0.1488 - precision: 0.6666 - recall: 0.9364
# Epoch 84: val_auc did not improve from 0.89983
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.7229 - auc: 0.8353 - loss: 0.1486 - precision: 0.6573 - recall: 0.9314 - val_accuracy: 0.7725 - val_auc: 0.8980 - val_loss: 0.1559 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 4.6875e-06
# Epoch 85/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.
val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.7429 - auc: 0.8525 - loss: 0.1443 - precision: 0.6742 - recall: 0.9400 - val_accuracy: 0.7725 - val_auc: 0.8982 - val_loss: 0.1553 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 1.1719e-06
# Epoch 105/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.7218 - auc: 0.8447 - loss: 0.1442 - precision: 0.6600 - recall: 0.9522
# Epoch 105: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.7243 - auc: 0.8412 - loss: 0.1447 - precision: 0.6548 - recall: 0.9486 - val_accuracy: 0.7725 - val_auc: 0.8982 - val_loss: 0.1557 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 1.1719e-06
# Epoch 106/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7508 - auc: 0.8509 - loss: 0.1433 - precision: 0.6877 - recall: 0.9479
# Epoch 106: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 0.7471 - auc: 0.8590 - loss: 0.1434 - precision: 0.6776 - recall: 0.9429 - val_accuracy: 0.7725 - val_auc: 0.8983 - val_loss: 0.1549 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 1.1719e-06
# Epoch 107/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7677 - auc: 0.8479 - loss: 0.1432 - precision: 0.7027 - recall: 0.9551
# Epoch 107: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.7471 - auc: 0.8447 - loss: 0.1442 - precision: 0.6762 - recall: 0.9486 - val_accuracy: 0.7725 - val_auc: 0.8993 - val_loss: 0.1537 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 1.1719e-06
# Epoch 108/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7516 - auc: 0.8497 - loss: 0.1437 - precision: 0.6896 - recall: 0.9443
# Epoch 108: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.7414 - auc: 0.8560 - loss: 0.1436 - precision: 0.6735 - recall: 0.9371 - val_accuracy: 0.7725 - val_auc: 0.8979 - val_loss: 0.1539 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 1.1719e-06
# Epoch 109/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7449 - auc: 0.8422 - loss: 0.1444 - precision: 0.6847 - recall: 0.9408
# Epoch 109: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.7300 - auc: 0.8460 - loss: 0.1444 - precision: 0.6633 - recall: 0.9343 - val_accuracy: 0.7725 - val_auc: 0.8989 - val_loss: 0.1543 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 1.1719e-06
# Epoch 110/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7641 - auc: 0.8507 - loss: 0.1440 - precision: 0.7060 - recall: 0.9308
# Epoch 110: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.7386 - auc: 0.8431 - loss: 0.1449 - precision: 0.6751 - recall: 0.9200 - val_accuracy: 0.7725 - val_auc: 0.8986 - val_loss: 0.1537 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 1.1719e-06
# Epoch 111/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7214 - auc: 0.8433 - loss: 0.1446 - precision: 0.6692 - recall: 0.9114
# Epoch 111: ReduceLROnPlateau reducing learning rate to 5.859375278305379e-07.
#
# Epoch 111: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.7086 - auc: 0.8350 - loss: 0.1455 - precision: 0.6515 - recall: 0.8971 - val_accuracy: 0.7725 - val_auc: 0.8986 - val_loss: 0.1537 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 1.1719e-06
# Epoch 112/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.7409 - auc: 0.8439 - loss: 0.1446 - precision: 0.6938 - recall: 0.8946
# Epoch 112: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.7257 - auc: 0.8491 - loss: 0.1442 - precision: 0.6653 - recall: 0.9086 - val_accuracy: 0.7725 - val_auc: 0.8995 - val_loss: 0.1541 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 5.8594e-07
# Epoch 113/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7070 - auc: 0.8322 - loss: 0.1451 - precision: 0.6557 - recall: 0.9114
# Epoch 113: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 195ms/step - accuracy: 0.7057 - auc: 0.8448 - loss: 0.1444 - precision: 0.6440 - recall: 0.9200 - val_accuracy: 0.7725 - val_auc: 0.8991 - val_loss: 0.1542 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 5.8594e-07
# Epoch 114/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7353 - auc: 0.8347 - loss: 0.1457 - precision: 0.6765 - recall: 0.9357
# Epoch 114: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - accuracy: 0.7186 - auc: 0.8374 - loss: 0.1452 - precision: 0.6533 - recall: 0.9314 - val_accuracy: 0.7725 - val_auc: 0.8984 - val_loss: 0.1553 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 5.8594e-07
# Epoch 115/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7307 - auc: 0.8323 - loss: 0.1447 - precision: 0.6757 - recall: 0.9213
# Epoch 115: val_auc did not improve from 0.90034
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.7171 - auc: 0.8408 - loss: 0.1447 - precision: 0.6526 - recall: 0.9286 - val_accuracy: 0.7725 - val_auc: 0.8991 - val_loss: 0.1550 - val_precision: 0.8696 - val_recall: 0.6383 - learning_rate: 5.8594e-07
# Epoch 115: early stopping
# Restoring model weights from the end of the best epoch: 95.

# %%
# 4) Evaluate with optimal threshold
y_pred, y_pred_proba, threshold = evaluate_with_optimal_threshold(model, X_test, y_test)
# Out:
# ======================================================================
# THRESHOLD OPTIMIZATION & EVALUATION
# ======================================================================
#
# Optimal threshold: 0.4405 (default=0.5)
#   At this threshold: TPR=0.8404, FPR=0.1368
#
# Results:
#   AUC-ROC: 0.8997
#   Accuracy (default threshold=0.5): 0.7725 (77.25%)
#   Accuracy (optimal threshold=0.4405): 0.8519 (85.19%)
#
# With optimal threshold:
#               precision    recall  f1-score   support
#
#   Non-Planet     0.8454    0.8632    0.8542        95
#       Planet     0.8587    0.8404    0.8495        94
#
#     accuracy                         0.8519       189
#    macro avg     0.8520    0.8518    0.8518       189
# weighted avg     0.8520    0.8519    0.8518       189
#
#
# Prediction distribution (optimal threshold):
#   Predicted 0: 97
#   Predicted 1: 92
# True distribution:
#   True 0: 95
#   True 1: 94

# %%
# Ensure results directory exists
results_dir = "../assignment2_taskF_results"
os.makedirs(results_dir, exist_ok=True)

# 5) Visualize & save artifacts
plot_all(
    y_test, y_pred, y_pred_proba, history, metadata_test, X_test, threshold,
    X_test_orig=X_test_orig, X_err_test=X_err_test, scaler=scaler
)

# Persist model and threshold
model.save(os.path.join(results_dir, 'tess_model_final.keras'))
np.save(os.path.join(results_dir, 'optimal_threshold.npy'), threshold)

print("\n" + "="*70)
print("TRAINING COMPLETE!")
print("="*70)
print("\nKey improvements:")
print("  ✓ Perfectly balanced training data")
print("  ✓ Focal loss for hard examples")
print("  ✓ Optimal threshold selection")
print("  ✓ AUC-focused optimization")
print("\nFiles:")
print(f"  - {results_dir}/tess_model_final.keras")
print(f"  - {results_dir}/best_model_final.keras")
print(f"  - {results_dir}/optimal_threshold.npy")
print(f"  - {results_dir}/confusion_matrix_final.png")
print(f"  - {results_dir}/training_history_final.png")
print(f"  - {results_dir}/sample_lightcurves_predictions.png")
print("="*70)
# Out:
# ======================================================================
# VISUALIZATIONS
# ======================================================================
# Saved: ../assignment2_taskF_results/confusion_matrix_final.png
# Saved: ../assignment2_taskF_results/training_history_final.png
#
# ======================================================================
# PLOTTING LIGHTCURVES WITH PREDICTIONS (n=6)
# ======================================================================
# Saved: ../assignment2_taskF_results/sample_lightcurves_predictions.png
#
# ======================================================================
# TRAINING COMPLETE!
# ======================================================================
#
# Key improvements:
#   ✓ Perfectly balanced training data
#   ✓ Focal loss for hard examples
#   ✓ Optimal threshold selection
#   ✓ AUC-focused optimization
#
# Files:
#   - ../assignment2_taskF_results/tess_model_final.keras
#   - ../assignment2_taskF_results/best_model_final.keras
#   - ../assignment2_taskF_results/optimal_threshold.npy
#   - ../assignment2_taskF_results/confusion_matrix_final.png
#   - ../assignment2_taskF_results/training_history_final.png
#   - ../assignment2_taskF_results/sample_lightcurves_predictions.png
# ======================================================================

# %% [markdown]
# ## 11. (Optional) One-Click: Run Everything
#
# This cell wraps all steps into a single function for convenience.

# %%
def main():
    X_train, X_test, y_train, y_test, metadata_test, X_test_orig, X_err_test, scaler = load_data(
        csv_path=CSV_PATH, n_bins=N_BINS
    )
    model = build_simple_cnn(n_bins=N_BINS)
    history = train_model(model, X_train, y_train, X_test, y_test, epochs=200)
    y_pred, y_pred_proba, threshold = evaluate_with_optimal_threshold(model, X_test, y_test)
    plot_all(y_test, y_pred, y_pred_proba, history, metadata_test, X_test, threshold,
             X_test_orig=X_test_orig, X_err_test=X_err_test, scaler=scaler)
    model.save('tess_model_final.keras')
    np.save('optimal_threshold.npy', threshold)

    print("\n" + "="*70)
    print("TRAINING COMPLETE!")
    print("="*70)
    print("\nKey improvements:")
    print("  ✓ Perfectly balanced training data")
    print("  ✓ Focal loss for hard examples")
    print("  ✓ Optimal threshold selection")
    print("  ✓ AUC-focused optimization")
    print("\nFiles:")
    print("  - tess_model_final.keras")
    print("  - best_model_final.keras")
    print("  - optimal_threshold.npy")
    print("  - confusion_matrix_final.png")
    print("  - training_history_final.png")
    print("  - sample_lightcurves_predictions.png")
    print("="*70)

# Uncomment to run end-to-end:
# main()

# %% [markdown]
# ## 12. Interpreting Results & Next Steps
#
# - **AUC-ROC** is the primary score during training. Inspect training curves to ensure you’re not overfitting.
# - **Confusion matrix** with counts and percentages helps quantify trade-offs at the **optimal threshold**.
# - **False positives** vs **false negatives**: use domain needs to decide how to tune `alpha`/`gamma` in focal loss or to move the threshold.
#
# **Ideas to try next**
#
# - Add **class-dependent augmentations** (e.g., transit-like dips for positives).
# - Calibrate probabilities (e.g., **Platt scaling**, **isotonic regression**) for better decision thresholds.
# - Incorporate additional channels (centroid motion, background, etc.) into a **multi-input** model.
# - Use **cross-validation** on the training set to measure variability across folds.

# %% [markdown]
# ---
#
# ### Appendix: Notes on Data Schema
#
# - Ensure your CSV contains **exactly** `n_bins` columns named `flux_0000 .. flux_{n_bins-1:04d}` and matching `flux_err_*` columns.
# - Metadata columns are optional for training but used for prettier plots.
#
# ### Troubleshooting
#
# - `ValueError: columns not found`: your CSV headers don’t match the expected names. Check `n_bins` and column prefixes.
# - `CUDA out of memory`: reduce `batch_size`, or limit GPU memory; try the provided GPU memory-growth snippet.
# - `AUC not improving`: try a bigger `samples_per_class`, more dropout, or adjust `gamma`/`alpha`.
#
# ---
