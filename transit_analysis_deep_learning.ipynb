# %% [markdown]
# # Final TESS Transit Classification — Optimized for Extreme Class Imbalance
#
# This notebook converts and expands the provided Python script into a fully documented, didactic, and **step-by-step** workflow.
# We train a 1D CNN to classify TESS light curves into *transit* (planet candidate) vs *non-transit* under **severe class imbalance**.
#
# **Key strategies covered:**
#
# - **Balanced augmentation** (equal samples per class) to mitigate imbalance during training.
# - **Focal loss** (tunable `gamma` and `alpha`) to emphasize hard examples and rare positives.
# - **Threshold optimization** using **Youden’s J** from the ROC curve (don’t use the default 0.5).
# - **Simplified CNN architecture** to reduce overfitting.
# - **AUC-centric monitoring** with early stopping and LR scheduling.
#
# > **What you’ll learn**
# >
# > 1. Why balanced training batches help under extreme imbalance.
# > 2. How focal loss reshapes the gradient to focus on hard/rare samples.
# > 3. How to pick a **data-driven** decision threshold that best trades off TPR/FPR.
# > 4. How to evaluate with AUC-ROC rather than accuracy (which can be misleading).
# > 5. How to visualize confusion matrices and sample light curves with predictions.

# %% [markdown]
# ## 1. Prerequisites & Data
#
# **Dependencies** (install if needed):
#
# ```bash
# pip install numpy pandas scikit-learn matplotlib tensorflow
# ```
#
# > We intentionally avoid additional plotting libraries to keep dependencies compact.
# > If you already have a working scientific Python/TensorFlow stack, you can skip installations.
#
# **Expected dataset**: a CSV file named **`tess_data.csv`** in the working directory with:
#
# - **Light-curve samples**: `flux_0000, flux_0001, ..., flux_0999` (or up to `n_bins-1`)
# - **Flux uncertainties**: `flux_err_0000, ..., flux_err_0999`
# - **Label**: `label` (0 = Non-Planet, 1 = Planet)
# - **Metadata** (used for plots/titles): `toi_name, tic, disp, period_d, t0_bjd, dur_hr, sector`
#
# You can change the filename or number of bins via parameters in the **Data Loading** section.

# %% [markdown]
# ## 2. Environment Setup
#
# Set up imports, suppress noisy warnings, and fix seeds for reproducibility.
# (Exact reproducibility on GPUs may still vary across hardware/driver versions.)

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try:
    import IPython
    working_directory = "/".join(
            IPython.extract_module_locals()[1]["__vsc_ipynb_file__"].split("/")[:-1]
        )
    print("Setting working directory to: ", working_directory)
    print(os.chdir(working_directory))
except Exception as e:
    print("It was impossible to set your directory as the current one because of the following message")
    print(e)
    print("The working directory is: ", os.getcwd())

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import tensorflow.keras.backend as K

# Reproducibility
np.random.seed(27)
tf.random.set_seed(27)

print("="*70)
print("FINAL TESS CLASSIFICATION")
print("="*70)

# Optional: make TF less eager to pre-allocate all GPU memory (if using GPU)
try:
    gpus = tf.config.experimental.list_physical_devices('GPU')
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    if gpus:
        print(f"Enabled memory growth for {len(gpus)} GPU(s).")
except Exception as e:
    print("GPU setup note:", e)

print("TF version:", tf.__version__)
# Out:
# Setting working directory to:  /ca25/comp_astro25
# None
# 2025-11-28 08:24:38.415691: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-28 08:24:39.280180: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-28 08:24:42.276050: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ======================================================================
# FINAL TESS CLASSIFICATION
# ======================================================================
# TF version: 2.20.0
# 2025-11-28 08:24:42.966604: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# ## 3. Focal Loss (for severe imbalance)
#
# **Why focal loss?** With extreme imbalance, the model can get “lazy”—it learns to do well by focusing on the majority class.
# Focal loss down-weights *easy* examples and concentrates gradient on *hard* ones by adding a modulating factor \((1 - p_t)^\gamma\).
# We also use class weighting via \(\alpha\) to up-weight the rare positive class.
#
# - **`gamma`** (focusing parameter): higher values put more emphasis on hard examples.
# - **`alpha`** (class weight): weight for positive class (1); negative class gets \(1 - \alpha\).

# %%
def focal_loss(gamma=2.5, alpha=0.75):
    """Focal loss optimized for severe imbalance (binary)."""
    def focal_loss_fixed(y_true, y_pred):
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)

        pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
        alpha_factor = tf.where(tf.equal(y_true, 1), alpha, 1 - alpha)
        focal_weight = alpha_factor * K.pow(1 - pt, gamma)
        bce = -K.log(pt)
        return K.mean(focal_weight * bce)
    return focal_loss_fixed

# %% [markdown]
# ## 4. Balanced Augmentation
#
# We **balance the training set** to a fixed number of samples per class.
# If a class has too few samples, we create augmented variants (noise, scale, shift, combo).
# This prevents the model from being swamped by the majority class during training.

# %%
def create_balanced_dataset(X, y, samples_per_class=400):
    """Create a perfectly balanced dataset via lightweight augmentations."""
    print("\n" + "="*70)
    print("CREATING BALANCED DATASET")
    print("="*70)

    X_class0 = X[y == 0]
    X_class1 = X[y == 1]

    print(f"Original - Class 0: {len(X_class0)}, Class 1: {len(X_class1)}")

    def augment_to_target(X_orig, n_target):
        if len(X_orig) >= n_target:
            idx = np.random.choice(len(X_orig), n_target, replace=False)
            return X_orig[idx]

        X_result = [X_orig]
        while len(np.vstack(X_result)) < n_target:
            # number we still need (cap to avoid oversampling too big chunks)
            n_needed = n_target - len(np.vstack(X_result))
            idx = np.random.choice(len(X_orig), min(len(X_orig), n_needed))

            aug_type = np.random.rand()
            if aug_type < 0.25:
                # Additive Gaussian noise
                X_aug = X_orig[idx] + np.random.normal(0, 0.01, (len(idx), X_orig.shape[1]))
            elif aug_type < 0.5:
                # Multiplicative scaling
                scale = 1.0 + np.random.uniform(-0.03, 0.03, (len(idx), 1))
                X_aug = X_orig[idx] * scale
            elif aug_type < 0.75:
                # Circular shift (time shift)
                shifts = np.random.randint(-20, 20, len(idx))
                X_aug = np.array([np.roll(X_orig[i], s) for i, s in zip(idx, shifts)])
            else:
                # Mild combo: small scale + small noise
                X_aug = X_orig[idx] * (1.0 + np.random.uniform(-0.02, 0.02, (len(idx), 1)))
                X_aug += np.random.normal(0, 0.008, X_aug.shape)

            X_result.append(X_aug)

        X_final = np.vstack(X_result)
        return X_final[:n_target]

    X0_bal = augment_to_target(X_class0, samples_per_class)
    X1_bal = augment_to_target(X_class1, samples_per_class)

    print(f"Balanced - Class 0: {len(X0_bal)}, Class 1: {len(X1_bal)}")

    X_balanced = np.vstack([X0_bal, X1_bal])
    y_balanced = np.concatenate([np.zeros(samples_per_class), np.ones(samples_per_class)])

    # Shuffle
    idx = np.arange(len(X_balanced))
    np.random.shuffle(idx)

    return X_balanced[idx], y_balanced[idx]

# %% [markdown]
# ## 5. Data Loading, Splitting & Standardization
#
# We split **before** augmentation (to avoid leakage), then **balance only the training split**.
# We standardize the flux (zero mean / unit variance) using statistics from the training set only.
#
# **Notes**
#
# - Error bars `X_err` are **not** standardized (kept in their original scale).
# - We keep the **test metadata** to produce nicer titles in the sample light-curve plots.

# %%
def load_data(csv_path='tess_data.csv', n_bins=1000):
    """Load CSV, split, balance train set, and standardize features."""
    print("\n" + "="*70)
    print("LOADING DATA")
    print("="*70)

    df = pd.read_csv(csv_path)
    print(f"Dataset: {df.shape[0]} samples")

    flux_cols = [f'flux_{i:04d}' for i in range(n_bins)]
    flux_err_cols = [f'flux_err_{i:04d}' for i in range(n_bins)]
    X = df[flux_cols].values
    X_err = df[flux_err_cols].values
    y = df['label'].values

    metadata_cols = ['toi_name', 'tic', 'label', 'disp', 'period_d', 't0_bjd', 'dur_hr', 'sector']
    metadata = df[metadata_cols]

    print("\nOriginal distribution:")
    print(f"  Class 0: {(y==0).sum()}, Class 1: {(y==1).sum()}")
    if (y==0).sum() > 0:
        print(f"  Ratio: {(y==1).sum() / (y==0).sum():.2f}:1")

    # Train/test split (keep errors aligned; stratify to preserve class ratio)
    X_train, X_test, y_train, y_test, X_err_train, X_err_test, idx_train, idx_test = train_test_split(
        X, y, X_err, np.arange(len(y)),
        test_size=0.2,
        random_state=42,
        stratify=y
    )

    print(f"\nInitial split - Train: {len(X_train)}, Test: {len(X_test)}")

    # Balance training set
    X_train, y_train = create_balanced_dataset(X_train, y_train, samples_per_class=350)

    # Standardize (fit on train, apply to test)
    print("\n" + "="*70)
    print("STANDARDIZATION")
    print("="*70)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    print(f"Train: mean={X_train.mean():.6f}, std={X_train.std():.6f}")
    print(f"Test:  mean={X_test.mean():.6f}, std={X_test.std():.6f}")

    # Reshape for Conv1D: (samples, timesteps, channels)
    X_train = X_train.reshape(-1, n_bins, 1)
    X_test = X_test.reshape(-1, n_bins, 1)

    metadata_test = metadata.iloc[idx_test].reset_index(drop=True)

    print(f"\nFinal - X_train: {X_train.shape}, X_test: {X_test.shape}")
    print(f"Train dist: 0={( y_train==0).sum()}, 1={(y_train==1).sum()}")

    # Return standardized test for model input, but also return the standardized
    # copy (X_test_orig) so we can inverse-transform for plotting with error bars.
    return X_train, X_test, y_train, y_test, metadata_test, X_test.copy(), X_err_test, scaler

# %% [markdown]
# ## 6. A Simpler 1D CNN (to curb overfitting)
#
# A compact ConvNet with **BatchNorm**, **Dropout**, and **Global Average Pooling** is often enough for
# noisy, small-ish 1D signals. We also add mild L2 on the dense layers. The goal is a strong baseline
# that generalizes well, not a gigantic model that memorizes.

# %%
def build_simple_cnn(n_bins=1000):
    """Simpler CNN to prevent overfitting on small datasets."""
    print("\n" + "="*70)
    print("BUILDING SIMPLIFIED CNN")
    print("="*70)

    model = models.Sequential([
        layers.Input(shape=(n_bins, 1)),

        # Feature extraction
        layers.Conv1D(64, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(2),
        layers.Dropout(0.3),

        layers.Conv1D(128, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(2),
        layers.Dropout(0.3),

        layers.Conv1D(256, kernel_size=3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.GlobalAveragePooling1D(),
        layers.Dropout(0.4),

        # Classification head
        layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),
        layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),
        layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.2),

        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0005),
        loss=focal_loss(gamma=2.5, alpha=0.75),
        metrics=['accuracy',
                 keras.metrics.Precision(name='precision'),
                 keras.metrics.Recall(name='recall'),
                 keras.metrics.AUC(name='auc')]
    )

    model.summary()
    print("\nUsing Focal Loss (gamma=2.5, alpha=0.75)")
    return model

# %% [markdown]
# ## 7. Training with AUC Monitoring, Early Stopping & LR Scheduling
#
# We monitor **validation AUC** (not accuracy) and:
#
# - **EarlyStopping** on `val_auc` with patience to stop when progress stalls.
# - **ReduceLROnPlateau** to gently lower the LR when AUC plateaus.
# - **ModelCheckpoint** to persist the best model by AUC.
#
# > Tip: If your dataset is *very* small, increase dropout and/or reduce dense layers further.

# %%
def train_model(model, X_train, y_train, X_val, y_val, epochs=100):
    """Train the model with AUC-centric callbacks."""
    print("\n" + "="*70)
    print("TRAINING")
    print("="*70)

    # Directory OUTSIDE this notebook
    results_dir = "../assignment2_taskF_results"
    os.makedirs(results_dir, exist_ok=True)

    callbacks = [
        EarlyStopping(
            monitor='val_auc',
            patience=20,
            restore_best_weights=True,
            mode='max',
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_auc',
            factor=0.5,
            patience=8,
            min_lr=1e-7,
            mode='max',
            verbose=1
        ),
        ModelCheckpoint(
            os.path.join(results_dir, 'best_model_final.keras'),
            monitor='val_auc',
            save_best_only=True,
            mode='max',
            verbose=1
        )
    ]

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=32,
        callbacks=callbacks,
        verbose=1
    )
    return history

# %% [markdown]
# ## 8. Evaluation with **Optimal Threshold** (don’t default to 0.5)
#
# The default threshold (0.5) is rarely optimal with imbalanced data.
# We compute ROC, then choose the threshold that maximizes **Youden’s J** (\(\mathrm{TPR} - \mathrm{FPR}\)).
# We report both the default and the optimal settings.

# %%
def evaluate_with_optimal_threshold(model, X_test, y_test):
    """Find an optimal threshold from ROC (Youden's J) and evaluate."""
    print("\n" + "="*70)
    print("THRESHOLD OPTIMIZATION & EVALUATION")
    print("="*70)

    y_pred_proba = model.predict(X_test, verbose=0).flatten()
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

    # Youden's J statistic
    j_scores = tpr - fpr
    optimal_idx = np.argmax(j_scores)
    optimal_threshold = thresholds[optimal_idx]

    print(f"\nOptimal threshold: {optimal_threshold:.4f} (default=0.5)")
    print(f"  At this threshold: TPR={tpr[optimal_idx]:.4f}, FPR={fpr[optimal_idx]:.4f}")

    # Predictions with optimal vs default thresholds
    y_pred_optimal = (y_pred_proba >= optimal_threshold).astype(int)
    y_pred_default = (y_pred_proba >= 0.5).astype(int)

    # Metrics
    acc_optimal = accuracy_score(y_test, y_pred_optimal)
    acc_default = accuracy_score(y_test, y_pred_default)
    auc = roc_auc_score(y_test, y_pred_proba)

    print("\nResults:")
    print(f"  AUC-ROC: {auc:.4f}")
    print(f"  Accuracy (default threshold=0.5): {acc_default:.4f} ({acc_default*100:.2f}%)")
    print(f"  Accuracy (optimal threshold={optimal_threshold:.4f}): {acc_optimal:.4f} ({acc_optimal*100:.2f}%)")

    print("\nWith optimal threshold:")
    print(classification_report(y_test, y_pred_optimal,
                                target_names=['Non-Planet', 'Planet'],
                                digits=4,
                                zero_division=0))

    print("\nPrediction distribution (optimal threshold):")
    print(f"  Predicted 0: {(y_pred_optimal == 0).sum()}")
    print(f"  Predicted 1: {(y_pred_optimal == 1).sum()}")
    print("True distribution:")
    print(f"  True 0: {(y_test == 0).sum()}")
    print(f"  True 1: {(y_test == 1).sum()}")

    return y_pred_optimal, y_pred_proba, optimal_threshold

# %% [markdown]
# ## 9. Visualization (Matplotlib-only)
#
# We save:
# - **Confusion matrix** (`confusion_matrix_final.png`) with counts and percentages.
# - **Training curves** (`training_history_final.png`).
# - **Sample light curves with predictions** (`sample_lightcurves_predictions.png`).
#
# > We use **Matplotlib** exclusively to minimize dependencies.

# %%
import os

def plot_lightcurves_with_predictions(X_test_orig, X_err_test, y_test, y_pred, y_pred_proba,
                                      metadata_test, scaler, threshold, n_samples=6,
                                      save_path=None):
    """Plot light curves with error bars and prediction info; save to file."""

    # Create results directory
    results_dir = "../assignment2_taskF_results"
    os.makedirs(results_dir, exist_ok=True)

    if save_path is None:
        save_path = os.path.join(results_dir, "sample_lightcurves_predictions.png")

    print("\n" + "="*70)
    print(f"PLOTTING LIGHTCURVES WITH PREDICTIONS (n={n_samples})")
    print("="*70)

    n_samples = min(n_samples, len(X_test_orig))

    # Select diverse samples: correct/incorrect for both classes
    correct_planet = np.where((y_test == 1) & (y_pred == 1))[0]
    incorrect_planet = np.where((y_test == 1) & (y_pred == 0))[0]
    correct_nonplanet = np.where((y_test == 0) & (y_pred == 0))[0]
    incorrect_nonplanet = np.where((y_test == 0) & (y_pred == 1))[0]

    selected_idx = []
    per_category = max(1, n_samples // 4)

    for idx_list in [correct_planet, incorrect_planet, correct_nonplanet, incorrect_nonplanet]:
        if len(idx_list) > 0:
            n_select = min(per_category, len(idx_list))
            selected_idx.extend(np.random.choice(idx_list, n_select, replace=False))

    while len(selected_idx) < n_samples:
        remaining = list(set(range(len(y_test))) - set(selected_idx))
        if remaining:
            selected_idx.append(np.random.choice(remaining))
        else:
            break

    selected_idx = np.array(selected_idx[:n_samples])

    # Figure layout
    n_cols = 2
    n_rows = (n_samples + n_cols - 1) // n_cols
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 4*n_rows))
    if n_samples == 1:
        axes = np.array([axes])
    axes = axes.flatten()

    for plot_i, idx in enumerate(selected_idx):
        ax = axes[plot_i]

        flux_norm = X_test_orig[idx].flatten()
        flux_err = X_err_test[idx]
        flux_original = scaler.inverse_transform(flux_norm.reshape(1, -1)).flatten()

        time_bins = np.arange(len(flux_original))

        # Metadata
        toi_name = metadata_test.loc[idx, 'toi_name']
        tic = metadata_test.loc[idx, 'tic']
        disp = metadata_test.loc[idx, 'disp']
        sector = metadata_test.loc[idx, 'sector']

        true_label = y_test[idx]
        pred_label = y_pred[idx]
        pred_prob = y_pred_proba[idx]

        is_correct = (true_label == pred_label)
        true_str = 'Transit' if true_label == 1 else 'Non-Transit'
        pred_str = 'Transit' if pred_label == 1 else 'Non-Transit'

        ax.errorbar(time_bins, flux_original, yerr=flux_err, fmt='o', markersize=2,
                    ecolor='gray', elinewidth=0.5, capsize=0, alpha=0.6, label='Data')

        baseline = np.median(flux_original)
        ax.axhline(baseline, linestyle='--', linewidth=1, alpha=0.7, label='Baseline')

        ax.set_xlabel('Time Bin', fontsize=10, fontweight='bold')
        ax.set_ylabel('Flux (original scale)', fontsize=10, fontweight='bold')
        ax.grid(True, alpha=0.3)
        ax.legend(loc='upper right', fontsize=8)

        status_symbol = '✓' if is_correct else '✗'
        color = 'green' if is_correct else 'red'
        title = (f'TOI {toi_name} (TIC {tic}, {disp}) - TESS Sector {sector}\n'
                 f'True: {true_str} | Pred: {pred_str} (p={pred_prob:.3f}) {status_symbol}')
        ax.set_title(title, fontsize=10, fontweight='bold', color=color, pad=10)

        for spine in ax.spines.values():
            spine.set_edgecolor(color)
            spine.set_linewidth(2.0)

    for j in range(n_samples, len(axes)):
        axes[j].axis('off')

    plt.suptitle(f'Sample Light-curve Predictions (Threshold={threshold:.3f})',
                 fontsize=14, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"Saved: {save_path}")
    plt.close()


def plot_all(y_test, y_pred, y_pred_proba, history, metadata_test, X_test, threshold,
             X_test_orig=None, X_err_test=None, scaler=None):

    print("\n" + "="*70)
    print("VISUALIZATIONS")
    print("="*70)

    # Directory for results
    results_dir = "../assignment2_taskF_results"
    os.makedirs(results_dir, exist_ok=True)

    # --- Confusion matrix ---
    cm = confusion_matrix(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(8, 6))
    im = ax.imshow(cm, interpolation='nearest', cmap='Blues')
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(2),
           yticks=np.arange(2),
           xticklabels=['Non-Planet', 'Planet'],
           yticklabels=['Non-Planet', 'Planet'],
           xlabel='Predicted', ylabel='True',
           title=f'Confusion Matrix (threshold={threshold:.3f})')

    total = cm.sum()
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            count = cm[i, j]
            pct = (count / total * 100) if total > 0 else 0.0
            ax.text(j, i, f"{count}\n({pct:.1f}%)", ha='center', va='center', color='black', fontsize=10)

    plt.tight_layout()
    cm_path = os.path.join(results_dir, 'confusion_matrix_final.png')
    plt.savefig(cm_path, dpi=300)
    print(f"Saved: {cm_path}")
    plt.close()

    # --- Training history ---
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    metrics = [('loss', 'Loss'), ('accuracy', 'Accuracy'),
               ('auc', 'AUC'), ('recall', 'Recall')]

    for idx, (metric, title) in enumerate(metrics):
        ax = axes[idx // 2, idx % 2]
        if metric in history.history and f'val_{metric}' in history.history:
            ax.plot(history.history[metric], label='Train', linewidth=2)
            ax.plot(history.history[f'val_{metric}'], label='Val', linewidth=2)
            ax.set_xlabel('Epoch')
            ax.set_ylabel(title)
            ax.set_title(f'{title} vs Epoch', fontweight='bold')
            ax.legend()
            ax.grid(alpha=0.3)

    plt.suptitle('Training History - Final Model', fontsize=14, fontweight='bold')
    plt.tight_layout()
    hist_path = os.path.join(results_dir, 'training_history_final.png')
    plt.savefig(hist_path, dpi=300)
    print(f"Saved: {hist_path}")
    plt.close()

    # --- Light curves ---
    if X_test_orig is not None and X_err_test is not None and scaler is not None:
        plot_lightcurves_with_predictions(
            X_test_orig, X_err_test, y_test, y_pred,
            y_pred_proba, metadata_test, scaler, threshold,
            n_samples=6,
            save_path=os.path.join(results_dir, "sample_lightcurves_predictions.png")
        )

# %% [markdown]
# ## 10. Run the Pipeline
#
# You can run the following cells **step by step**, or use the **end-to-end** cell.
#
# > If your CSV isn’t called `tess_data.csv`, change `CSV_PATH` below.

# %%
# Path to your dataset
CSV_PATH = 'tess_data.csv'   # <- change me if needed
N_BINS = 1000                # number of flux bins/columns per sample

# %%
# 1) Load and prepare data
X_train, X_test, y_train, y_test, metadata_test, X_test_orig, X_err_test, scaler = load_data(
    csv_path=CSV_PATH, n_bins=N_BINS
)
# Out:
# ======================================================================
# LOADING DATA
# ======================================================================
# Dataset: 944 samples
#
# Original distribution:
#   Class 0: 472, Class 1: 472
#   Ratio: 1.00:1
#
# Initial split - Train: 755, Test: 189
#
# ======================================================================
# CREATING BALANCED DATASET
# ======================================================================
# Original - Class 0: 377, Class 1: 378
# Balanced - Class 0: 350, Class 1: 350
#
# ======================================================================
# STANDARDIZATION
# ======================================================================
# Train: mean=-0.000000, std=1.000000
# Test:  mean=-0.003086, std=0.469879
#
# Final - X_train: (700, 1000, 1), X_test: (189, 1000, 1)
# Train dist: 0=350, 1=350

# %%
# 2) Build model
model = build_simple_cnn(n_bins=N_BINS)
# Out:
# ======================================================================
# BUILDING SIMPLIFIED CNN
# ======================================================================
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 1000, 64)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1000, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 500, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 500, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 500, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 500, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 250, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 250, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 250, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 250, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421,249 (1.61 MB)
#  Trainable params: 420,353 (1.60 MB)
#  Non-trainable params: 896 (3.50 KB)
# Using Focal Loss (gamma=2.5, alpha=0.75)

# %%
# 3) Train
history = train_model(model, X_train, y_train, X_test, y_test, epochs=200)
# Out:
# ======================================================================
# TRAINING
# ======================================================================
# Epoch 1/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4760 - auc: 0.7927 - loss: 0.0096 - precision: 0.4740 - recall: 1.0000
# Epoch 1: val_auc improved from None to 0.67464, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.5043 - auc: 0.8007 - loss: 0.0095 - precision: 0.5022 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.6746 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 2/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4792 - auc: 0.7939 - loss: 0.0096 - precision: 0.4755 - recall: 1.0000
# Epoch 2: val_auc improved from 0.67464 to 0.67626, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.5086 - auc: 0.8000 - loss: 0.0095 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.6763 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 3/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.4783 - auc: 0.7889 - loss: 0.0097 - precision: 0.4751 - recall: 1.0000
# Epoch 3: val_auc improved from 0.67626 to 0.67710, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.5100 - auc: 0.7910 - loss: 0.0095 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.6771 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 4/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4758 - auc: 0.8087 - loss: 0.0095 - precision: 0.4739 - recall: 1.0000
# Epoch 4: val_auc improved from 0.67710 to 0.68315, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.5071 - auc: 0.7937 - loss: 0.0095 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.6831 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 5/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.4800 - auc: 0.7964 - loss: 0.0096 - precision: 0.4760 - recall: 1.0000
# Epoch 5: val_auc improved from 0.68315 to 0.70224, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.5114 - auc: 0.7885 - loss: 0.0095 - precision: 0.5058 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7022 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 6/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4752 - auc: 0.7990 - loss: 0.0096 - precision: 0.4736 - recall: 1.0000
# Epoch 6: val_auc improved from 0.70224 to 0.70711, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.5043 - auc: 0.8007 - loss: 0.0094 - precision: 0.5022 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7071 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 7/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.4756 - auc: 0.7913 - loss: 0.0096 - precision: 0.4738 - recall: 1.0000
# Epoch 7: val_auc improved from 0.70711 to 0.71769, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.5057 - auc: 0.7899 - loss: 0.0095 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7177 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 8/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4791 - auc: 0.7965 - loss: 0.0096 - precision: 0.4755 - recall: 1.0000
# Epoch 8: val_auc improved from 0.71769 to 0.72710, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5114 - auc: 0.8002 - loss: 0.0094 - precision: 0.5058 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7271 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 9/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4796 - auc: 0.7928 - loss: 0.0096 - precision: 0.4757 - recall: 1.0000
# Epoch 9: val_auc improved from 0.72710 to 0.73007, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.5100 - auc: 0.7964 - loss: 0.0094 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7301 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 10/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4760 - auc: 0.8158 - loss: 0.0094 - precision: 0.4740 - recall: 1.0000
# Epoch 10: val_auc did not improve from 0.73007
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5057 - auc: 0.8117 - loss: 0.0094 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7277 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 11/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4786 - auc: 0.7938 - loss: 0.0095 - precision: 0.4752 - recall: 1.0000
# Epoch 11: val_auc improved from 0.73007 to 0.73035, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.5086 - auc: 0.7976 - loss: 0.0094 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7303 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 12/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4775 - auc: 0.8137 - loss: 0.0095 - precision: 0.4747 - recall: 1.0000
# Epoch 12: val_auc improved from 0.73035 to 0.73040, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.5071 - auc: 0.8133 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7304 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 13/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4785 - auc: 0.7982 - loss: 0.0096 - precision: 0.4752 - recall: 1.0000
# Epoch 13: val_auc improved from 0.73040 to 0.73180, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.5071 - auc: 0.8072 - loss: 0.0094 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7318 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 14/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4790 - auc: 0.8048 - loss: 0.0095 - precision: 0.4754 - recall: 1.0000
# Epoch 14: val_auc did not improve from 0.73180
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5086 - auc: 0.8036 - loss: 0.0094 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7318 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 15/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4758 - auc: 0.8020 - loss: 0.0095 - precision: 0.4739 - recall: 1.0000
# Epoch 15: val_auc did not improve from 0.73180
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5057 - auc: 0.8054 - loss: 0.0094 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7317 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 16/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.4762 - auc: 0.7733 - loss: 0.0097 - precision: 0.4741 - recall: 1.0000
# Epoch 16: val_auc improved from 0.73180 to 0.73191, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.5071 - auc: 0.7842 - loss: 0.0095 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7319 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 17/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4784 - auc: 0.7899 - loss: 0.0096 - precision: 0.4752 - recall: 1.0000
# Epoch 17: val_auc improved from 0.73191 to 0.74155, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5086 - auc: 0.7916 - loss: 0.0094 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7415 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 18/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4784 - auc: 0.8050 - loss: 0.0095 - precision: 0.4751 - recall: 1.0000
# Epoch 18: val_auc improved from 0.74155 to 0.74798, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5071 - auc: 0.8090 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7480 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 19/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.4777 - auc: 0.7749 - loss: 0.0096 - precision: 0.4748 - recall: 1.0000
# Epoch 19: val_auc improved from 0.74798 to 0.75039, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.5086 - auc: 0.7848 - loss: 0.0094 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7504 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 20/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4782 - auc: 0.7893 - loss: 0.0096 - precision: 0.4750 - recall: 1.0000
# Epoch 20: val_auc did not improve from 0.75039
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.5057 - auc: 0.8012 - loss: 0.0094 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7367 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 21/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4799 - auc: 0.7865 - loss: 0.0096 - precision: 0.4759 - recall: 1.0000
# Epoch 21: val_auc did not improve from 0.75039
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5100 - auc: 0.8030 - loss: 0.0093 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7367 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 22/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4807 - auc: 0.8124 - loss: 0.0094 - precision: 0.4761 - recall: 1.0000
# Epoch 22: val_auc did not improve from 0.75039
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5071 - auc: 0.8060 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7370 - val_loss: 0.0110 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 23/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.4787 - auc: 0.8014 - loss: 0.0095 - precision: 0.4753 - recall: 1.0000
# Epoch 23: val_auc did not improve from 0.75039
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.5100 - auc: 0.8113 - loss: 0.0093 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7366 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 24/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4828 - auc: 0.7824 - loss: 0.0095 - precision: 0.4773 - recall: 1.0000
# Epoch 24: val_auc did not improve from 0.75039
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.5129 - auc: 0.8000 - loss: 0.0093 - precision: 0.5065 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7366 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 25/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4784 - auc: 0.7967 - loss: 0.0095 - precision: 0.4751 - recall: 1.0000
# Epoch 25: val_auc did not improve from 0.75039
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5071 - auc: 0.7954 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7390 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 26/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4796 - auc: 0.7937 - loss: 0.0095 - precision: 0.4757 - recall: 1.0000
# Epoch 26: val_auc did not improve from 0.75039
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5100 - auc: 0.8005 - loss: 0.0093 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7390 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 27/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4771 - auc: 0.7930 - loss: 0.0095 - precision: 0.4745 - recall: 1.0000
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
#
# Epoch 27: val_auc did not improve from 0.75039
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.5057 - auc: 0.7968 - loss: 0.0093 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7390 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 1.9531e-06
# Epoch 28/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4807 - auc: 0.8019 - loss: 0.0094 - precision: 0.4762 - recall: 1.0000
# Epoch 28: val_auc improved from 0.75039 to 0.75078, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5086 - auc: 0.8094 - loss: 0.0093 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7508 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 29/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4786 - auc: 0.7897 - loss: 0.0095 - precision: 0.4753 - recall: 1.0000
# Epoch 29: val_auc did not improve from 0.75078
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5086 - auc: 0.8051 - loss: 0.0093 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7461 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 30/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4865 - auc: 0.7876 - loss: 0.0095 - precision: 0.4790 - recall: 1.0000
# Epoch 30: val_auc improved from 0.75078 to 0.75314, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.5129 - auc: 0.8015 - loss: 0.0093 - precision: 0.5065 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7531 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 31/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4788 - auc: 0.7983 - loss: 0.0095 - precision: 0.4753 - recall: 1.0000
# Epoch 31: val_auc did not improve from 0.75314
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5071 - auc: 0.7987 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7461 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 32/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4777 - auc: 0.7806 - loss: 0.0096 - precision: 0.4748 - recall: 1.0000
# Epoch 32: val_auc did not improve from 0.75314
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.5057 - auc: 0.7950 - loss: 0.0094 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7508 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 33/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4844 - auc: 0.7981 - loss: 0.0094 - precision: 0.4779 - recall: 1.0000
# Epoch 33: val_auc did not improve from 0.75314
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.5114 - auc: 0.7904 - loss: 0.0094 - precision: 0.5058 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7461 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 34/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.4796 - auc: 0.8045 - loss: 0.0094 - precision: 0.4757 - recall: 1.0000
# Epoch 34: val_auc did not improve from 0.75314
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.5100 - auc: 0.8123 - loss: 0.0092 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7497 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 35/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4800 - auc: 0.7876 - loss: 0.0095 - precision: 0.4759 - recall: 1.0000
# Epoch 35: val_auc did not improve from 0.75314
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5086 - auc: 0.7893 - loss: 0.0094 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7478 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 36/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4774 - auc: 0.7866 - loss: 0.0095 - precision: 0.4747 - recall: 1.0000
# Epoch 36: val_auc improved from 0.75314 to 0.75431, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.5086 - auc: 0.7987 - loss: 0.0093 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7543 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 37/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4832 - auc: 0.7947 - loss: 0.0095 - precision: 0.4773 - recall: 1.0000
# Epoch 37: val_auc improved from 0.75431 to 0.77587, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.5071 - auc: 0.7960 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7759 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 38/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4790 - auc: 0.7883 - loss: 0.0095 - precision: 0.4754 - recall: 0.9985
# Epoch 38: val_auc did not improve from 0.77587
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.5071 - auc: 0.8081 - loss: 0.0092 - precision: 0.5036 - recall: 0.9971 - val_accuracy: 0.4974 - val_auc: 0.7647 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 39/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4778 - auc: 0.8078 - loss: 0.0094 - precision: 0.4748 - recall: 1.0000
# Epoch 39: val_auc did not improve from 0.77587
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.5086 - auc: 0.8044 - loss: 0.0093 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7635 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 40/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4824 - auc: 0.7844 - loss: 0.0095 - precision: 0.4771 - recall: 1.0000
# Epoch 40: val_auc did not improve from 0.77587
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.5114 - auc: 0.7880 - loss: 0.0094 - precision: 0.5058 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7723 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 41/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4799 - auc: 0.7815 - loss: 0.0095 - precision: 0.4759 - recall: 1.0000
# Epoch 41: val_auc did not improve from 0.77587
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.5071 - auc: 0.7963 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7723 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 42/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4800 - auc: 0.7988 - loss: 0.0094 - precision: 0.4759 - recall: 1.0000
# Epoch 42: val_auc improved from 0.77587 to 0.77604, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.5071 - auc: 0.7949 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7760 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 43/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4809 - auc: 0.8028 - loss: 0.0094 - precision: 0.4762 - recall: 1.0000
# Epoch 43: val_auc did not improve from 0.77604
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.5057 - auc: 0.8015 - loss: 0.0093 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7760 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 44/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4820 - auc: 0.7797 - loss: 0.0095 - precision: 0.4767 - recall: 1.0000
# Epoch 44: val_auc improved from 0.77604 to 0.79849, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5100 - auc: 0.7870 - loss: 0.0094 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7985 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 45/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4788 - auc: 0.7972 - loss: 0.0094 - precision: 0.4753 - recall: 1.0000
# Epoch 45: val_auc did not improve from 0.79849
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5057 - auc: 0.7857 - loss: 0.0094 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7985 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 46/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4762 - auc: 0.7768 - loss: 0.0095 - precision: 0.4741 - recall: 1.0000
# Epoch 46: val_auc did not improve from 0.79849
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.5057 - auc: 0.7991 - loss: 0.0093 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7985 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 47/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4824 - auc: 0.8000 - loss: 0.0094 - precision: 0.4771 - recall: 1.0000
# Epoch 47: val_auc did not improve from 0.79849
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5114 - auc: 0.7877 - loss: 0.0093 - precision: 0.5058 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7985 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 48/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4781 - auc: 0.7791 - loss: 0.0095 - precision: 0.4750 - recall: 1.0000
# Epoch 48: val_auc did not improve from 0.79849
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.5057 - auc: 0.7851 - loss: 0.0093 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7985 - val_loss: 0.0109 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 49/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4777 - auc: 0.7890 - loss: 0.0095 - precision: 0.4748 - recall: 1.0000
# Epoch 49: val_auc improved from 0.79849 to 0.80084, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.5086 - auc: 0.7965 - loss: 0.0093 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8008 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 50/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4795 - auc: 0.7939 - loss: 0.0094 - precision: 0.4756 - recall: 1.0000
# Epoch 50: val_auc did not improve from 0.80084
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5071 - auc: 0.8029 - loss: 0.0092 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8008 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 51/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4784 - auc: 0.8034 - loss: 0.0094 - precision: 0.4751 - recall: 1.0000
# Epoch 51: val_auc did not improve from 0.80084
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5057 - auc: 0.8011 - loss: 0.0093 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8008 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 52/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4791 - auc: 0.8019 - loss: 0.0094 - precision: 0.4755 - recall: 1.0000
# Epoch 52: val_auc did not improve from 0.80084
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.5100 - auc: 0.8014 - loss: 0.0092 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7988 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 53/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4834 - auc: 0.8049 - loss: 0.0094 - precision: 0.4775 - recall: 1.0000
# Epoch 53: val_auc did not improve from 0.80084
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.5100 - auc: 0.8063 - loss: 0.0092 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7941 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 54/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4780 - auc: 0.7992 - loss: 0.0094 - precision: 0.4750 - recall: 1.0000
# Epoch 54: val_auc did not improve from 0.80084
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5057 - auc: 0.8054 - loss: 0.0092 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.7985 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 55/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4825 - auc: 0.8128 - loss: 0.0093 - precision: 0.4772 - recall: 1.0000
# Epoch 55: val_auc improved from 0.80084 to 0.81265, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.5129 - auc: 0.8061 - loss: 0.0092 - precision: 0.5065 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8127 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 56/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4736 - auc: 0.7970 - loss: 0.0094 - precision: 0.4728 - recall: 1.0000
# Epoch 56: val_auc improved from 0.81265 to 0.81792, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.5029 - auc: 0.8034 - loss: 0.0092 - precision: 0.5014 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8179 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 57/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4810 - auc: 0.8061 - loss: 0.0093 - precision: 0.4764 - recall: 1.0000
# Epoch 57: val_auc improved from 0.81792 to 0.82548, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.5086 - auc: 0.8046 - loss: 0.0092 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8255 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 58/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4783 - auc: 0.8006 - loss: 0.0093 - precision: 0.4751 - recall: 1.0000
# Epoch 58: val_auc did not improve from 0.82548
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5071 - auc: 0.7927 - loss: 0.0093 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8130 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 59/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4816 - auc: 0.7977 - loss: 0.0094 - precision: 0.4767 - recall: 1.0000
# Epoch 59: val_auc did not improve from 0.82548
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.5129 - auc: 0.7959 - loss: 0.0093 - precision: 0.5065 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8231 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 60/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4796 - auc: 0.8014 - loss: 0.0094 - precision: 0.4757 - recall: 1.0000
# Epoch 60: val_auc improved from 0.82548 to 0.82816, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.5071 - auc: 0.8027 - loss: 0.0092 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8282 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 61/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4840 - auc: 0.7952 - loss: 0.0094 - precision: 0.4777 - recall: 1.0000
# Epoch 61: val_auc improved from 0.82816 to 0.83315, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.5086 - auc: 0.8057 - loss: 0.0092 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8331 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 62/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4791 - auc: 0.8033 - loss: 0.0093 - precision: 0.4755 - recall: 1.0000
# Epoch 62: val_auc did not improve from 0.83315
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5086 - auc: 0.8043 - loss: 0.0092 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8255 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 63/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4767 - auc: 0.7924 - loss: 0.0094 - precision: 0.4743 - recall: 0.9985
# Epoch 63: val_auc improved from 0.83315 to 0.83320, saving model to ../assignment2_taskF_results/best_model_final.keras
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.5043 - auc: 0.7952 - loss: 0.0092 - precision: 0.5022 - recall: 0.9971 - val_accuracy: 0.4974 - val_auc: 0.8332 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 64/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4787 - auc: 0.7798 - loss: 0.0094 - precision: 0.4753 - recall: 1.0000
# Epoch 64: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.5086 - auc: 0.7960 - loss: 0.0092 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8282 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 65/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4782 - auc: 0.8085 - loss: 0.0093 - precision: 0.4750 - recall: 1.0000
# Epoch 65: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.5057 - auc: 0.8030 - loss: 0.0092 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8282 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 66/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4817 - auc: 0.8164 - loss: 0.0092 - precision: 0.4766 - recall: 1.0000
# Epoch 66: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5086 - auc: 0.8087 - loss: 0.0091 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8130 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 67/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4782 - auc: 0.7947 - loss: 0.0094 - precision: 0.4750 - recall: 1.0000
# Epoch 67: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.5071 - auc: 0.7978 - loss: 0.0092 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8282 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 68/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.4833 - auc: 0.7835 - loss: 0.0094 - precision: 0.4774 - recall: 1.0000
# Epoch 68: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.5071 - auc: 0.7998 - loss: 0.0092 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8332 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 69/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4807 - auc: 0.7966 - loss: 0.0094 - precision: 0.4762 - recall: 1.0000
# Epoch 69: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
#
# Epoch 69: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.5100 - auc: 0.7985 - loss: 0.0092 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8088 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 9.7656e-07
# Epoch 70/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4777 - auc: 0.8003 - loss: 0.0093 - precision: 0.4748 - recall: 1.0000
# Epoch 70: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5071 - auc: 0.8012 - loss: 0.0092 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8088 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 4.8828e-07
# Epoch 71/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.4785 - auc: 0.8113 - loss: 0.0093 - precision: 0.4752 - recall: 1.0000
# Epoch 71: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.5086 - auc: 0.8068 - loss: 0.0091 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8251 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 4.8828e-07
# Epoch 72/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4783 - auc: 0.8002 - loss: 0.0093 - precision: 0.4751 - recall: 1.0000
# Epoch 72: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5086 - auc: 0.7999 - loss: 0.0092 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8227 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 4.8828e-07
# Epoch 73/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4763 - auc: 0.7994 - loss: 0.0093 - precision: 0.4741 - recall: 1.0000
# Epoch 73: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5057 - auc: 0.8051 - loss: 0.0092 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8088 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 4.8828e-07
# Epoch 74/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.4778 - auc: 0.8115 - loss: 0.0093 - precision: 0.4748 - recall: 1.0000
# Epoch 74: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.5086 - auc: 0.8054 - loss: 0.0092 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8088 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 4.8828e-07
# Epoch 75/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.4765 - auc: 0.7908 - loss: 0.0094 - precision: 0.4742 - recall: 1.0000
# Epoch 75: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.5057 - auc: 0.7953 - loss: 0.0092 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8227 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 4.8828e-07
# Epoch 76/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.4817 - auc: 0.7974 - loss: 0.0093 - precision: 0.4767 - recall: 1.0000
# Epoch 76: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5100 - auc: 0.8050 - loss: 0.0091 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8136 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 4.8828e-07
# Epoch 77/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4775 - auc: 0.8025 - loss: 0.0093 - precision: 0.4748 - recall: 1.0000
# Epoch 77: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
#
# Epoch 77: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5086 - auc: 0.7985 - loss: 0.0092 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8046 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 4.8828e-07
# Epoch 78/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4761 - auc: 0.8014 - loss: 0.0094 - precision: 0.4740 - recall: 1.0000
# Epoch 78: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.5057 - auc: 0.8036 - loss: 0.0092 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8040 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 2.4414e-07
# Epoch 79/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4783 - auc: 0.7685 - loss: 0.0095 - precision: 0.4751 - recall: 1.0000
# Epoch 79: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.5086 - auc: 0.7903 - loss: 0.0092 - precision: 0.5043 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8044 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 2.4414e-07
# Epoch 80/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4809 - auc: 0.7850 - loss: 0.0094 - precision: 0.4764 - recall: 1.0000
# Epoch 80: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.5114 - auc: 0.7985 - loss: 0.0092 - precision: 0.5058 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8276 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 2.4414e-07
# Epoch 81/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4771 - auc: 0.7941 - loss: 0.0093 - precision: 0.4745 - recall: 1.0000
# Epoch 81: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.5057 - auc: 0.7956 - loss: 0.0092 - precision: 0.5029 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8175 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 2.4414e-07
# Epoch 82/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.4790 - auc: 0.7972 - loss: 0.0093 - precision: 0.4754 - recall: 1.0000
# Epoch 82: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.5100 - auc: 0.7978 - loss: 0.0092 - precision: 0.5051 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8227 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 2.4414e-07
# Epoch 83/200
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4780 - auc: 0.7805 - loss: 0.0094 - precision: 0.4749 - recall: 1.0000
# Epoch 83: val_auc did not improve from 0.83320
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.5071 - auc: 0.7934 - loss: 0.0092 - precision: 0.5036 - recall: 1.0000 - val_accuracy: 0.4974 - val_auc: 0.8276 - val_loss: 0.0108 - val_precision: 0.4974 - val_recall: 1.0000 - learning_rate: 2.4414e-07
# Epoch 83: early stopping
# Restoring model weights from the end of the best epoch: 63.

# %%
# 4) Evaluate with optimal threshold
y_pred, y_pred_proba, threshold = evaluate_with_optimal_threshold(model, X_test, y_test)
# Out:
# ======================================================================
# THRESHOLD OPTIMIZATION & EVALUATION
# ======================================================================
#
# Optimal threshold: 0.7094 (default=0.5)
#   At this threshold: TPR=0.8511, FPR=0.1368
#
# Results:
#   AUC-ROC: 0.8703
#   Accuracy (default threshold=0.5): 0.4974 (49.74%)
#   Accuracy (optimal threshold=0.7094): 0.8571 (85.71%)
#
# With optimal threshold:
#               precision    recall  f1-score   support
#
#   Non-Planet     0.8542    0.8632    0.8586        95
#       Planet     0.8602    0.8511    0.8556        94
#
#     accuracy                         0.8571       189
#    macro avg     0.8572    0.8571    0.8571       189
# weighted avg     0.8572    0.8571    0.8571       189
#
#
# Prediction distribution (optimal threshold):
#   Predicted 0: 96
#   Predicted 1: 93
# True distribution:
#   True 0: 95
#   True 1: 94

# %%
# Ensure results directory exists
results_dir = "../assignment2_taskF_results"
os.makedirs(results_dir, exist_ok=True)

# 5) Visualize & save artifacts
plot_all(
    y_test, y_pred, y_pred_proba, history, metadata_test, X_test, threshold,
    X_test_orig=X_test_orig, X_err_test=X_err_test, scaler=scaler
)

# Persist model and threshold
model.save(os.path.join(results_dir, 'tess_model_final.keras'))
np.save(os.path.join(results_dir, 'optimal_threshold.npy'), threshold)

print("\n" + "="*70)
print("TRAINING COMPLETE!")
print("="*70)
print("\nKey improvements:")
print("  ✓ Perfectly balanced training data")
print("  ✓ Focal loss for hard examples")
print("  ✓ Optimal threshold selection")
print("  ✓ AUC-focused optimization")
print("\nFiles:")
print(f"  - {results_dir}/tess_model_final.keras")
print(f"  - {results_dir}/best_model_final.keras")
print(f"  - {results_dir}/optimal_threshold.npy")
print(f"  - {results_dir}/confusion_matrix_final.png")
print(f"  - {results_dir}/training_history_final.png")
print(f"  - {results_dir}/sample_lightcurves_predictions.png")
print("="*70)
# Out:
# ======================================================================
# VISUALIZATIONS
# ======================================================================
# Saved: ../assignment2_taskF_results/confusion_matrix_final.png
# Saved: ../assignment2_taskF_results/training_history_final.png
#
# ======================================================================
# PLOTTING LIGHTCURVES WITH PREDICTIONS (n=6)
# ======================================================================
# Saved: ../assignment2_taskF_results/sample_lightcurves_predictions.png
#
# ======================================================================
# TRAINING COMPLETE!
# ======================================================================
#
# Key improvements:
#   ✓ Perfectly balanced training data
#   ✓ Focal loss for hard examples
#   ✓ Optimal threshold selection
#   ✓ AUC-focused optimization
#
# Files:
#   - ../assignment2_taskF_results/tess_model_final.keras
#   - ../assignment2_taskF_results/best_model_final.keras
#   - ../assignment2_taskF_results/optimal_threshold.npy
#   - ../assignment2_taskF_results/confusion_matrix_final.png
#   - ../assignment2_taskF_results/training_history_final.png
#   - ../assignment2_taskF_results/sample_lightcurves_predictions.png
# ======================================================================

# %% [markdown]
# ## 11. (Optional) One-Click: Run Everything
#
# This cell wraps all steps into a single function for convenience.

# %%
def main():
    X_train, X_test, y_train, y_test, metadata_test, X_test_orig, X_err_test, scaler = load_data(
        csv_path=CSV_PATH, n_bins=N_BINS
    )
    model = build_simple_cnn(n_bins=N_BINS)
    history = train_model(model, X_train, y_train, X_test, y_test, epochs=200)
    y_pred, y_pred_proba, threshold = evaluate_with_optimal_threshold(model, X_test, y_test)
    plot_all(y_test, y_pred, y_pred_proba, history, metadata_test, X_test, threshold,
             X_test_orig=X_test_orig, X_err_test=X_err_test, scaler=scaler)
    model.save('tess_model_final.keras')
    np.save('optimal_threshold.npy', threshold)

    print("\n" + "="*70)
    print("TRAINING COMPLETE!")
    print("="*70)
    print("\nKey improvements:")
    print("  ✓ Perfectly balanced training data")
    print("  ✓ Focal loss for hard examples")
    print("  ✓ Optimal threshold selection")
    print("  ✓ AUC-focused optimization")
    print("\nFiles:")
    print("  - tess_model_final.keras")
    print("  - best_model_final.keras")
    print("  - optimal_threshold.npy")
    print("  - confusion_matrix_final.png")
    print("  - training_history_final.png")
    print("  - sample_lightcurves_predictions.png")
    print("="*70)

# Uncomment to run end-to-end:
# main()

# %% [markdown]
# ## 12. Interpreting Results & Next Steps
#
# - **AUC-ROC** is the primary score during training. Inspect training curves to ensure you’re not overfitting.
# - **Confusion matrix** with counts and percentages helps quantify trade-offs at the **optimal threshold**.
# - **False positives** vs **false negatives**: use domain needs to decide how to tune `alpha`/`gamma` in focal loss or to move the threshold.
#
# **Ideas to try next**
#
# - Add **class-dependent augmentations** (e.g., transit-like dips for positives).
# - Calibrate probabilities (e.g., **Platt scaling**, **isotonic regression**) for better decision thresholds.
# - Incorporate additional channels (centroid motion, background, etc.) into a **multi-input** model.
# - Use **cross-validation** on the training set to measure variability across folds.

# %% [markdown]
# ---
#
# ### Appendix: Notes on Data Schema
#
# - Ensure your CSV contains **exactly** `n_bins` columns named `flux_0000 .. flux_{n_bins-1:04d}` and matching `flux_err_*` columns.
# - Metadata columns are optional for training but used for prettier plots.
#
# ### Troubleshooting
#
# - `ValueError: columns not found`: your CSV headers don’t match the expected names. Check `n_bins` and column prefixes.
# - `CUDA out of memory`: reduce `batch_size`, or limit GPU memory; try the provided GPU memory-growth snippet.
# - `AUC not improving`: try a bigger `samples_per_class`, more dropout, or adjust `gamma`/`alpha`.
#
# ---
